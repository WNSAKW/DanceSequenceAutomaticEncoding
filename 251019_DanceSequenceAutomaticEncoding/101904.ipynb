# %%
# --- 匯入套件 ---
import os
import json
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler

# %%
# =========================================================
# Step 1: 批次讀取多個 CSV 檔案
# =========================================================
data_dir = "./dance_csv/"  # ← 這裡改成放你CSV檔的資料夾
all_poses = []

def parse_point(s):
    s = s.strip("()")
    parts = [float(p.strip(" '")) for p in s.split(",")]
    return parts

for file in os.listdir(data_dir):
    if file.endswith(".csv"):
        csv_path = os.path.join(data_dir, file)
        df = pd.read_csv(csv_path)
        pose_cols = [c for c in df.columns if c != "frame"]
        poses = []
        for _, row in df.iterrows():
            pose = []
            for c in pose_cols:
                pose += parse_point(row[c])
            poses.append(pose)
        all_poses.append(np.array(poses))
        print(f"✅ 已載入：{file}, 共 {len(poses)} 幀")
# Out:
# ✅ 已載入：Ballet_1.csv, 共 241 幀
# ✅ 已載入：Ballet_10.csv, 共 70 幀
# ✅ 已載入：Ballet_11.csv, 共 832 幀
# ✅ 已載入：Ballet_12.csv, 共 9 幀
# ✅ 已載入：Ballet_13.csv, 共 18 幀
# ✅ 已載入：Ballet_14.csv, 共 1167 幀
# ✅ 已載入：Ballet_15.csv, 共 3 幀
# ✅ 已載入：Ballet_16.csv, 共 48 幀
# ✅ 已載入：Ballet_17.csv, 共 481 幀
# ✅ 已載入：Ballet_18.csv, 共 61 幀
# ✅ 已載入：Ballet_19.csv, 共 229 幀
# ✅ 已載入：Ballet_2.csv, 共 15 幀
# ✅ 已載入：Ballet_20.csv, 共 55 幀
# ✅ 已載入：Ballet_21.csv, 共 224 幀
# ✅ 已載入：Ballet_22.csv, 共 369 幀
# ✅ 已載入：Ballet_23.csv, 共 79 幀
# ✅ 已載入：Ballet_24.csv, 共 319 幀
# ✅ 已載入：Ballet_25.csv, 共 155 幀
# ✅ 已載入：Ballet_26.csv, 共 171 幀
# ✅ 已載入：Ballet_27.csv, 共 25 幀
# ✅ 已載入：Ballet_28.csv, 共 79 幀
# ✅ 已載入：Ballet_29.csv, 共 1283 幀
# ✅ 已載入：Ballet_3.csv, 共 1832 幀
# ✅ 已載入：Ballet_30.csv, 共 583 幀
# ✅ 已載入：Ballet_31.csv, 共 389 幀
# ✅ 已載入：Ballet_32.csv, 共 554 幀
# ✅ 已載入：Ballet_33.csv, 共 182 幀
# ✅ 已載入：Ballet_34.csv, 共 86 幀
# ✅ 已載入：Ballet_35.csv, 共 78 幀
# ✅ 已載入：Ballet_36.csv, 共 447 幀
# ✅ 已載入：Ballet_37.csv, 共 347 幀
# ✅ 已載入：Ballet_38.csv, 共 76 幀
# ✅ 已載入：Ballet_39.csv, 共 167 幀
# ✅ 已載入：Ballet_4.csv, 共 58 幀
# ✅ 已載入：Ballet_40.csv, 共 593 幀
# ✅ 已載入：Ballet_41.csv, 共 635 幀
# ✅ 已載入：Ballet_42.csv, 共 75 幀
# ✅ 已載入：Ballet_43.csv, 共 2866 幀
# ✅ 已載入：Ballet_44.csv, 共 27 幀
# ✅ 已載入：Ballet_45.csv, 共 821 幀
# ✅ 已載入：Ballet_46.csv, 共 122 幀
# ✅ 已載入：Ballet_47.csv, 共 2837 幀
# ✅ 已載入：Ballet_48.csv, 共 368 幀
# ✅ 已載入：Ballet_5.csv, 共 1686 幀
# ✅ 已載入：Ballet_6.csv, 共 312 幀
# ✅ 已載入：Ballet_7.csv, 共 283 幀
# ✅ 已載入：Ballet_8.csv, 共 724 幀
# ✅ 已載入：Ballet_9.csv, 共 19 幀
# ✅ 已載入：JiaJiangDance_49.csv, 共 108 幀
# ✅ 已載入：JiaJiangDance_50.csv, 共 18 幀
# ✅ 已載入：JiaJiangDance_51.csv, 共 138 幀
# ✅ 已載入：JiaJiangDance_52.csv, 共 64 幀
# ✅ 已載入：JiaJiangDance_53.csv, 共 159 幀
# ✅ 已載入：JiaJiangDance_54.csv, 共 45 幀
# ✅ 已載入：JiaJiangDance_55.csv, 共 110 幀
# ✅ 已載入：JiaJiangDance_56.csv, 共 19 幀
# ✅ 已載入：JiaJiangDance_57.csv, 共 584 幀
# ✅ 已載入：JiaJiangDance_58.csv, 共 92 幀
# ✅ 已載入：JiaJiangDance_59.csv, 共 13 幀
# ✅ 已載入：JiaJiangDance_60.csv, 共 103 幀
# ✅ 已載入：JiaJiangDance_61.csv, 共 192 幀
# ✅ 已載入：JiaJiangDance_62.csv, 共 208 幀
# ✅ 已載入：JiaJiangDance_63.csv, 共 285 幀
# ✅ 已載入：JiaJiangDance_64.csv, 共 276 幀
# ✅ 已載入：JiaJiangDance_65.csv, 共 309 幀
# ✅ 已載入：JiaJiangDance_66.csv, 共 820 幀
# ✅ 已載入：JiaJiangDance_67.csv, 共 1461 幀
# ✅ 已載入：JiaJiangDance_68.csv, 共 205 幀
# ✅ 已載入：JiaJiangDance_69.csv, 共 186 幀
# ✅ 已載入：JiaJiangDance_70.csv, 共 205 幀
# ✅ 已載入：JiaJiangDance_71.csv, 共 183 幀
# ✅ 已載入：JiaJiangDance_72.csv, 共 205 幀
# ✅ 已載入：JiaJiangDance_73.csv, 共 264 幀
# ✅ 已載入：JiaJiangDance_74.csv, 共 495 幀
# ✅ 已載入：StreetDance_251.csv, 共 1409 幀
# ✅ 已載入：StreetDance_75.csv, 共 3139 幀
# ✅ 已載入：StreetDance_76.csv, 共 2657 幀
# ✅ 已載入：StreetDance_77.csv, 共 561 幀
# ✅ 已載入：StreetDance_78.csv, 共 360 幀
# ✅ 已載入：StreetDance_79.csv, 共 332 幀
# ✅ 已載入：StreetDance_80.csv, 共 314 幀
# ✅ 已載入：StreetDance_81.csv, 共 91 幀
# ✅ 已載入：StreetDance_82.csv, 共 289 幀
# ✅ 已載入：StreetDance_83.csv, 共 349 幀
# ✅ 已載入：StreetDance_84.csv, 共 164 幀
# ✅ 已載入：StreetDance_85.csv, 共 1749 幀
# ✅ 已載入：StreetDance_86.csv, 共 108 幀
# ✅ 已載入：StreetDance_87.csv, 共 1050 幀
# ✅ 已載入：StreetDance_88.csv, 共 5953 幀
# ✅ 已載入：StreetDance_89.csv, 共 2126 幀
# ✅ 已載入：StreetDance_90.csv, 共 1333 幀
# ✅ 已載入：StreetDance_91.csv, 共 371 幀
# ✅ 已載入：StreetDance_92.csv, 共 5441 幀
# ✅ 已載入：StreetDance_93.csv, 共 3387 幀
# ✅ 已載入：TaiwaneseAboriginalDance_100.csv, 共 986 幀
# ✅ 已載入：TaiwaneseAboriginalDance_101.csv, 共 808 幀
# ✅ 已載入：TaiwaneseAboriginalDance_102.csv, 共 12 幀
# ✅ 已載入：TaiwaneseAboriginalDance_103.csv, 共 266 幀
# ✅ 已載入：TaiwaneseAboriginalDance_104.csv, 共 17 幀
# ✅ 已載入：TaiwaneseAboriginalDance_105.csv, 共 288 幀
# ✅ 已載入：TaiwaneseAboriginalDance_106.csv, 共 4978 幀
# ✅ 已載入：TaiwaneseAboriginalDance_107.csv, 共 7054 幀
# ✅ 已載入：TaiwaneseAboriginalDance_108.csv, 共 2161 幀
# ✅ 已載入：TaiwaneseAboriginalDance_109.csv, 共 630 幀
# ✅ 已載入：TaiwaneseAboriginalDance_110.csv, 共 1111 幀
# ✅ 已載入：TaiwaneseAboriginalDance_111.csv, 共 486 幀
# ✅ 已載入：TaiwaneseAboriginalDance_112.csv, 共 23 幀
# ✅ 已載入：TaiwaneseAboriginalDance_113.csv, 共 534 幀
# ✅ 已載入：TaiwaneseAboriginalDance_114.csv, 共 47 幀
# ✅ 已載入：TaiwaneseAboriginalDance_115.csv, 共 1885 幀
# ✅ 已載入：TaiwaneseAboriginalDance_116.csv, 共 505 幀
# ✅ 已載入：TaiwaneseAboriginalDance_117.csv, 共 15 幀
# ✅ 已載入：TaiwaneseAboriginalDance_118.csv, 共 454 幀
# ✅ 已載入：TaiwaneseAboriginalDance_119.csv, 共 1509 幀
# ✅ 已載入：TaiwaneseAboriginalDance_120.csv, 共 11 幀
# ✅ 已載入：TaiwaneseAboriginalDance_121.csv, 共 153 幀
# ✅ 已載入：TaiwaneseAboriginalDance_122.csv, 共 39 幀
# ✅ 已載入：TaiwaneseAboriginalDance_123.csv, 共 713 幀
# ✅ 已載入：TaiwaneseAboriginalDance_124.csv, 共 1222 幀
# ✅ 已載入：TaiwaneseAboriginalDance_125.csv, 共 286 幀
# ✅ 已載入：TaiwaneseAboriginalDance_126.csv, 共 281 幀
# ✅ 已載入：TaiwaneseAboriginalDance_127.csv, 共 243 幀
# ✅ 已載入：TaiwaneseAboriginalDance_128.csv, 共 38 幀
# ✅ 已載入：TaiwaneseAboriginalDance_129.csv, 共 115 幀
# ✅ 已載入：TaiwaneseAboriginalDance_130.csv, 共 125 幀
# ✅ 已載入：TaiwaneseAboriginalDance_131.csv, 共 1999 幀
# ✅ 已載入：TaiwaneseAboriginalDance_132.csv, 共 472 幀
# ✅ 已載入：TaiwaneseAboriginalDance_133.csv, 共 159 幀
# ✅ 已載入：TaiwaneseAboriginalDance_134.csv, 共 1100 幀
# ✅ 已載入：TaiwaneseAboriginalDance_135.csv, 共 22 幀
# ✅ 已載入：TaiwaneseAboriginalDance_136.csv, 共 1143 幀
# ✅ 已載入：TaiwaneseAboriginalDance_137.csv, 共 4160 幀
# ✅ 已載入：TaiwaneseAboriginalDance_138.csv, 共 1181 幀
# ✅ 已載入：TaiwaneseAboriginalDance_139.csv, 共 794 幀
# ✅ 已載入：TaiwaneseAboriginalDance_140.csv, 共 19 幀
# ✅ 已載入：TaiwaneseAboriginalDance_141.csv, 共 438 幀
# ✅ 已載入：TaiwaneseAboriginalDance_142.csv, 共 64 幀
# ✅ 已載入：TaiwaneseAboriginalDance_143.csv, 共 15 幀
# ✅ 已載入：TaiwaneseAboriginalDance_144.csv, 共 179 幀
# ✅ 已載入：TaiwaneseAboriginalDance_145.csv, 共 59 幀
# ✅ 已載入：TaiwaneseAboriginalDance_146.csv, 共 456 幀
# ✅ 已載入：TaiwaneseAboriginalDance_147.csv, 共 456 幀
# ✅ 已載入：TaiwaneseAboriginalDance_148.csv, 共 96 幀
# ✅ 已載入：TaiwaneseAboriginalDance_149.csv, 共 1590 幀
# ✅ 已載入：TaiwaneseAboriginalDance_150.csv, 共 23 幀
# ✅ 已載入：TaiwaneseAboriginalDance_151.csv, 共 30 幀
# ✅ 已載入：TaiwaneseAboriginalDance_152.csv, 共 2509 幀
# ✅ 已載入：TaiwaneseAboriginalDance_153.csv, 共 1717 幀
# ✅ 已載入：TaiwaneseAboriginalDance_154.csv, 共 25 幀
# ✅ 已載入：TaiwaneseAboriginalDance_155.csv, 共 492 幀
# ✅ 已載入：TaiwaneseAboriginalDance_156.csv, 共 707 幀
# ✅ 已載入：TaiwaneseAboriginalDance_157.csv, 共 34 幀
# ✅ 已載入：TaiwaneseAboriginalDance_158.csv, 共 12 幀
# ✅ 已載入：TaiwaneseAboriginalDance_159.csv, 共 5660 幀
# ✅ 已載入：TaiwaneseAboriginalDance_160.csv, 共 4971 幀
# ✅ 已載入：TaiwaneseAboriginalDance_161.csv, 共 66 幀
# ✅ 已載入：TaiwaneseAboriginalDance_162.csv, 共 60 幀
# ✅ 已載入：TaiwaneseAboriginalDance_163.csv, 共 1084 幀
# ✅ 已載入：TaiwaneseAboriginalDance_164.csv, 共 38 幀
# ✅ 已載入：TaiwaneseAboriginalDance_165.csv, 共 1753 幀
# ✅ 已載入：TaiwaneseAboriginalDance_166.csv, 共 2596 幀
# ✅ 已載入：TaiwaneseAboriginalDance_167.csv, 共 294 幀
# ✅ 已載入：TaiwaneseAboriginalDance_168.csv, 共 182 幀
# ✅ 已載入：TaiwaneseAboriginalDance_169.csv, 共 284 幀
# ✅ 已載入：TaiwaneseAboriginalDance_170.csv, 共 26 幀
# ✅ 已載入：TaiwaneseAboriginalDance_171.csv, 共 12 幀
# ✅ 已載入：TaiwaneseAboriginalDance_172.csv, 共 271 幀
# ✅ 已載入：TaiwaneseAboriginalDance_173.csv, 共 22 幀
# ✅ 已載入：TaiwaneseAboriginalDance_174.csv, 共 697 幀
# ✅ 已載入：TaiwaneseAboriginalDance_175.csv, 共 1383 幀
# ✅ 已載入：TaiwaneseAboriginalDance_176.csv, 共 31 幀
# ✅ 已載入：TaiwaneseAboriginalDance_177.csv, 共 525 幀
# ✅ 已載入：TaiwaneseAboriginalDance_178.csv, 共 190 幀
# ✅ 已載入：TaiwaneseAboriginalDance_179.csv, 共 671 幀
# ✅ 已載入：TaiwaneseAboriginalDance_180.csv, 共 4578 幀
# ✅ 已載入：TaiwaneseAboriginalDance_181.csv, 共 235 幀
# ✅ 已載入：TaiwaneseAboriginalDance_182.csv, 共 144 幀
# ✅ 已載入：TaiwaneseAboriginalDance_183.csv, 共 19 幀
# ✅ 已載入：TaiwaneseAboriginalDance_184.csv, 共 2448 幀
# ✅ 已載入：TaiwaneseAboriginalDance_185.csv, 共 23 幀
# ✅ 已載入：TaiwaneseAboriginalDance_186.csv, 共 25 幀
# ✅ 已載入：TaiwaneseAboriginalDance_187.csv, 共 2370 幀
# ✅ 已載入：TaiwaneseAboriginalDance_188.csv, 共 31 幀
# ✅ 已載入：TaiwaneseAboriginalDance_189.csv, 共 103 幀
# ✅ 已載入：TaiwaneseAboriginalDance_190.csv, 共 5920 幀
# ✅ 已載入：TaiwaneseAboriginalDance_191.csv, 共 8063 幀
# ✅ 已載入：TaiwaneseAboriginalDance_192.csv, 共 2427 幀
# ✅ 已載入：TaiwaneseAboriginalDance_193.csv, 共 1589 幀
# ✅ 已載入：TaiwaneseAboriginalDance_194.csv, 共 90 幀
# ✅ 已載入：TaiwaneseAboriginalDance_195.csv, 共 567 幀
# ✅ 已載入：TaiwaneseAboriginalDance_196.csv, 共 2628 幀
# ✅ 已載入：TaiwaneseAboriginalDance_197.csv, 共 14 幀
# ✅ 已載入：TaiwaneseAboriginalDance_198.csv, 共 1178 幀
# ✅ 已載入：TaiwaneseAboriginalDance_199.csv, 共 5347 幀
# ✅ 已載入：TaiwaneseAboriginalDance_200.csv, 共 1868 幀
# ✅ 已載入：TaiwaneseAboriginalDance_201.csv, 共 42 幀
# ✅ 已載入：TaiwaneseAboriginalDance_202.csv, 共 195 幀
# ✅ 已載入：TaiwaneseAboriginalDance_203.csv, 共 2362 幀
# ✅ 已載入：TaiwaneseAboriginalDance_204.csv, 共 36 幀
# ✅ 已載入：TaiwaneseAboriginalDance_205.csv, 共 902 幀
# ✅ 已載入：TaiwaneseAboriginalDance_206.csv, 共 776 幀
# ✅ 已載入：TaiwaneseAboriginalDance_207.csv, 共 7171 幀
# ✅ 已載入：TaiwaneseAboriginalDance_208.csv, 共 6992 幀
# ✅ 已載入：TaiwaneseAboriginalDance_209.csv, 共 1964 幀
# ✅ 已載入：TaiwaneseAboriginalDance_210.csv, 共 1385 幀
# ✅ 已載入：TaiwaneseAboriginalDance_211.csv, 共 15 幀
# ✅ 已載入：TaiwaneseAboriginalDance_212.csv, 共 1972 幀
# ✅ 已載入：TaiwaneseAboriginalDance_213.csv, 共 2167 幀
# ✅ 已載入：TaiwaneseAboriginalDance_214.csv, 共 3547 幀
# ✅ 已載入：TaiwaneseAboriginalDance_215.csv, 共 1385 幀
# ✅ 已載入：TaiwaneseAboriginalDance_216.csv, 共 1969 幀
# ✅ 已載入：TaiwaneseAboriginalDance_217.csv, 共 6126 幀
# ✅ 已載入：TaiwaneseAboriginalDance_218.csv, 共 1403 幀
# ✅ 已載入：TaiwaneseAboriginalDance_219.csv, 共 217 幀
# ✅ 已載入：TaiwaneseAboriginalDance_220.csv, 共 1346 幀
# ✅ 已載入：TaiwaneseAboriginalDance_221.csv, 共 517 幀
# ✅ 已載入：TaiwaneseAboriginalDance_222.csv, 共 55 幀
# ✅ 已載入：TaiwaneseAboriginalDance_223.csv, 共 141 幀
# ✅ 已載入：TaiwaneseAboriginalDance_224.csv, 共 491 幀
# ✅ 已載入：TaiwaneseAboriginalDance_225.csv, 共 38 幀
# ✅ 已載入：TaiwaneseAboriginalDance_226.csv, 共 121 幀
# ✅ 已載入：TaiwaneseAboriginalDance_227.csv, 共 1586 幀
# ✅ 已載入：TaiwaneseAboriginalDance_228.csv, 共 247 幀
# ✅ 已載入：TaiwaneseAboriginalDance_229.csv, 共 569 幀
# ✅ 已載入：TaiwaneseAboriginalDance_230.csv, 共 107 幀
# ✅ 已載入：TaiwaneseAboriginalDance_231.csv, 共 1025 幀
# ✅ 已載入：TaiwaneseAboriginalDance_232.csv, 共 220 幀
# ✅ 已載入：TaiwaneseAboriginalDance_233.csv, 共 540 幀
# ✅ 已載入：TaiwaneseAboriginalDance_234.csv, 共 2747 幀
# ✅ 已載入：TaiwaneseAboriginalDance_235.csv, 共 39 幀
# ✅ 已載入：TaiwaneseAboriginalDance_236.csv, 共 14 幀
# ✅ 已載入：TaiwaneseAboriginalDance_237.csv, 共 4 幀
# ✅ 已載入：TaiwaneseAboriginalDance_238.csv, 共 300 幀
# ✅ 已載入：TaiwaneseAboriginalDance_94.csv, 共 1274 幀
# ✅ 已載入：TaiwaneseAboriginalDance_95.csv, 共 1856 幀
# ✅ 已載入：TaiwaneseAboriginalDance_96.csv, 共 5563 幀
# ✅ 已載入：TaiwaneseAboriginalDance_97.csv, 共 10 幀
# ✅ 已載入：TaiwaneseAboriginalDance_98.csv, 共 6894 幀
# ✅ 已載入：TaiwaneseAboriginalDance_99.csv, 共 50 幀
# ✅ 已載入：TapDance_239.csv, 共 3581 幀
# ✅ 已載入：TapDance_240.csv, 共 1386 幀
# ✅ 已載入：TapDance_241.csv, 共 4778 幀
# ✅ 已載入：TapDance_242.csv, 共 2707 幀
# ✅ 已載入：TapDance_243.csv, 共 4134 幀
# ✅ 已載入：TapDance_244.csv, 共 3798 幀
# ✅ 已載入：TapDance_245.csv, 共 3260 幀
# ✅ 已載入：TapDance_246.csv, 共 3638 幀
# ✅ 已載入：TapDance_247.csv, 共 3412 幀
# ✅ 已載入：TapDance_248.csv, 共 3312 幀
# ✅ 已載入：TapDance_249.csv, 共 55 幀
# ✅ 已載入：TapDance_250.csv, 共 3294 幀

# %%
# 合併所有 CSV
all_poses = np.concatenate(all_poses, axis=0)
print("📦 全部骨架資料 shape:", all_poses.shape)  # (總幀數, 99)
# Out:
# 📦 全部骨架資料 shape: (271194, 99)

# %%
# =========================================================
# Step 2: 正規化
# =========================================================
scaler = StandardScaler()
all_poses = scaler.fit_transform(all_poses)

# %%
# =========================================================
# Step 3: 定義 Dataset / DataLoader
# =========================================================
class PoseDataset(Dataset):
    def __init__(self, data):
        self.data = torch.tensor(data, dtype=torch.float32)
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        return self.data[idx]

dataset = PoseDataset(all_poses)
dataloader = DataLoader(dataset, batch_size=64, shuffle=False)

# %%
# =========================================================
# Step 4: 定義模型架構（需與訓練時一致）
# =========================================================
class VectorQuantizer(nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.embedding_dim = embedding_dim
        self.num_embeddings = num_embeddings
        self.embedding = nn.Embedding(num_embeddings, embedding_dim)
        self.embedding.weight.data.uniform_(-1/num_embeddings, 1/num_embeddings)

    def forward(self, x):
        distances = (
            torch.sum(x**2, dim=1, keepdim=True)
            + torch.sum(self.embedding.weight**2, dim=1)
            - 2 * torch.matmul(x, self.embedding.weight.t())
        )
        encoding_indices = torch.argmin(distances, dim=1)
        quantized = self.embedding(encoding_indices)
        return quantized, encoding_indices

# %%
class VQVAE(nn.Module):
    def __init__(self, input_dim=99, hidden_dim=128, latent_dim=32, num_embeddings=64):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, latent_dim)
        )
        self.vq = VectorQuantizer(num_embeddings, latent_dim)
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        z_q, indices = self.vq(z)
        x_recon = self.decoder(z_q)
        return x_recon, indices, z, z_q

# %%
# =========================================================
# Step 5: 載入訓練好的模型
# =========================================================
device = "cuda" if torch.cuda.is_available() else "cpu"
model = VQVAE().to(device)

model_path = "vqvae_model.pth"  # ← 你的模型權重檔案
if os.path.exists(model_path):
    model.load_state_dict(torch.load(model_path, map_location=device))
    print(f"✅ 已載入模型權重：{model_path}")
else:
    raise FileNotFoundError(f"❌ 找不到模型檔案：{model_path}")

model.eval()
# Out:
# ✅ 已載入模型權重：vqvae_model.pth
# C:\Users\user\AppData\Local\Temp\ipykernel_27440\2112891260.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# VQVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=99, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=32, bias=True)
#   )
#   (vq): VectorQuantizer(
#     (embedding): Embedding(64, 32)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=32, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=99, bias=True)
#   )
# )

# %%
# =========================================================
# Step 6: 生成符號序列
# =========================================================
all_indices = []

with torch.no_grad():
    for batch in dataloader:
        batch = batch.to(device)
        _, indices, _, _ = model(batch)
        all_indices.extend(indices.cpu().numpy().tolist())

# %%
# 把每個 index 映射成符號 (A-Z, a-z, 0-9 循環)
def index_to_symbol(i):
    symbols = [chr(c) for c in range(65, 91)] + [chr(c) for c in range(97, 123)] + [str(d) for d in range(10)]
    return symbols[i % len(symbols)]

symbol_sequence = [index_to_symbol(i) for i in all_indices]

# %%
# =========================================================
# Step 7: 儲存成 JSON
# =========================================================
output_path = "symbol_sequences.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(symbol_sequence, f, ensure_ascii=False, indent=2)

print(f"✅ 已輸出符號序列 JSON：{output_path}")
print("符號預覽：", "".join(symbol_sequence[:200]))
# Out:
# ✅ 已輸出符號序列 JSON：symbol_sequences.json
# 符號預覽： eeeeeeeeeeiieeiieeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeieeeeeeeeeeeeeeeeeeeeeeeeeeeeeeiiiiiiiiiiiiiiiieeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeiiiiii
