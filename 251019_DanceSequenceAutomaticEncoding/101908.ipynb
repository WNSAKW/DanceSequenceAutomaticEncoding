# %%
# --- 匯入套件 ---
import os
import glob
import pandas as pd
import numpy as np
import json
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# --- Step 1: 讀取多個 CSV ---
csv_folder = "./dance_csv/"  # 你的 CSV 資料夾
csv_files = glob.glob(os.path.join(csv_folder, "*.csv"))
print(f"找到 {len(csv_files)} 個 CSV 檔案")
# Out:
# 找到 251 個 CSV 檔案

# %%
def parse_point(s):
    s = s.strip("()")
    parts = [float(p.strip(" '")) for p in s.split(",")]
    return parts

def load_pose_csv(path):
    df = pd.read_csv(path)
    pose_cols = [c for c in df.columns if c != "frame"]
    poses = []
    for i, row in df.iterrows():
        pose = []
        for c in pose_cols:
            pose += parse_point(row[c])
        poses.append(pose)
    poses = np.array(poses)
    delta_poses = np.diff(poses, axis=0)
    delta_poses = np.vstack([delta_poses, np.zeros_like(delta_poses[0])])
    return delta_poses

# %%
# --- Step 2: 收集所有資料以便標準化 ---
all_data = []
file_data = {}
for path in csv_files:
    delta = load_pose_csv(path)
    if len(delta) < 10:
        print(f"⚠️ 檔案太短，略過：{os.path.basename(path)}（只有 {len(delta)} 幀）")
        continue
    all_data.append(delta)
    file_data[path] = delta

all_data = np.concatenate(all_data, axis=0)
print("總資料 shape:", all_data.shape)

scaler = StandardScaler()
scaler.fit(all_data)
# Out:
# ⚠️ 檔案太短，略過：Ballet_12.csv（只有 9 幀）
# ⚠️ 檔案太短，略過：Ballet_15.csv（只有 3 幀）
# ⚠️ 檔案太短，略過：TaiwaneseAboriginalDance_237.csv（只有 4 幀）
# 總資料 shape: (271178, 99)
# StandardScaler()

# %%
# --- Step 3: Dataset ---
class PoseDataset(Dataset):
    def __init__(self, data, seq_len=10):
        self.data = torch.tensor(data, dtype=torch.float32)
        self.seq_len = seq_len
    def __len__(self):
        return max(0, len(self.data) - self.seq_len)
    def __getitem__(self, idx):
        seq = self.data[idx:idx+self.seq_len]
        return seq, seq

# %%
# --- Step 4: LSTM Autoencoder ---
class LSTMAutoencoder(nn.Module):
    def __init__(self, input_dim=99, hidden_dim=128, latent_dim=32):
        super().__init__()
        self.encoder = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc_enc = nn.Linear(hidden_dim, latent_dim)
        self.fc_dec = nn.Linear(latent_dim, hidden_dim)
        self.decoder = nn.LSTM(hidden_dim, input_dim, batch_first=True)
    def forward(self, x):
        enc_out, (h, c) = self.encoder(x)
        latent = self.fc_enc(enc_out[:, -1, :])
        dec_input = self.fc_dec(latent).unsqueeze(1).repeat(1, x.size(1), 1)
        dec_out, _ = self.decoder(dec_input)
        return dec_out, latent

# %%
# --- Step 5: 訓練模型 ---
device = "cuda" if torch.cuda.is_available() else "cpu"
model = LSTMAutoencoder().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()

# %%
seq_len = 10
dataset = PoseDataset(all_data, seq_len)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True)

# %%
epochs = 30
for epoch in range(epochs):
    total_loss = 0
    for batch, _ in dataloader:
        batch = batch.to(device)
        optimizer.zero_grad()
        recon, latent = model(batch)
        loss = loss_fn(recon, batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(dataloader):.4f}")
# Out:
# Epoch 1/30, Loss: 0.0312
# Epoch 2/30, Loss: 0.0238
# Epoch 3/30, Loss: 0.0212
# Epoch 4/30, Loss: 0.0188
# Epoch 5/30, Loss: 0.0177
# Epoch 6/30, Loss: 0.0171
# Epoch 7/30, Loss: 0.0168
# Epoch 8/30, Loss: 0.0165
# Epoch 9/30, Loss: 0.0163
# Epoch 10/30, Loss: 0.0160
# Epoch 11/30, Loss: 0.0157
# Epoch 12/30, Loss: 0.0155
# Epoch 13/30, Loss: 0.0154
# Epoch 14/30, Loss: 0.0153
# Epoch 15/30, Loss: 0.0153
# Epoch 16/30, Loss: 0.0152
# Epoch 17/30, Loss: 0.0151
# Epoch 18/30, Loss: 0.0150
# Epoch 19/30, Loss: 0.0154
# Epoch 20/30, Loss: 0.0166
# Epoch 21/30, Loss: 0.0154
# Epoch 22/30, Loss: 0.0149
# Epoch 23/30, Loss: 0.0150
# Epoch 24/30, Loss: 0.0146
# Epoch 25/30, Loss: 0.0146
# Epoch 26/30, Loss: 0.0149
# Epoch 27/30, Loss: 0.0146
# Epoch 28/30, Loss: 0.0144
# Epoch 29/30, Loss: 0.0143
# Epoch 30/30, Loss: 0.0142

# %%
# --- Step 6: 為每個 CSV 生成符號 ---
model.eval()
symbol_dict = {}

for path, data in file_data.items():
    if len(data) < seq_len:
        continue
    data = scaler.transform(data)
    ds = PoseDataset(data, seq_len)
    if len(ds) == 0:
        print(f"⚠️ {os.path.basename(path)} 長度不足，跳過")
        continue
    dl = DataLoader(ds, batch_size=64, shuffle=False)

    latents = []
    with torch.no_grad():
        for batch, _ in dl:
            batch = batch.to(device)
            _, latent = model(batch)
            latents.append(latent.cpu().numpy())

    latents = np.concatenate(latents, axis=0)
    print(f"{os.path.basename(path)} latent 數量:", len(latents))

    num_symbols = min(26, len(latents))
    if num_symbols < 2:
        print(f"⚠️ {os.path.basename(path)} 樣本太少，跳過此檔案")
        continue

    kmeans = KMeans(n_clusters=num_symbols, random_state=42, n_init=10)
    labels = kmeans.fit_predict(latents)
    symbols = [chr(65 + l) for l in labels]
    symbol_seq = "".join(symbols)
    print(f"{os.path.basename(path)} → 符號長度 {len(symbol_seq)}，前50個：{symbol_seq[:50]}")

    # 🔹 加入到字典中
    symbol_dict[os.path.basename(path)] = symbol_seq
# Out:
# Ballet_1.csv latent 數量: 231
# Ballet_1.csv → 符號長度 231，前50個：QNEJAPGTRXCVOKHVLOYXYMPOYBLXOMPOYBYXMPILPQKJMFDWBX
# Ballet_10.csv latent 數量: 60
# Ballet_10.csv → 符號長度 60，前50個：MCMCWMEYRPUXSLNZDVFHQJGKIOMEEETTETEETBEBBABABABABA
# Ballet_11.csv latent 數量: 822
# Ballet_11.csv → 符號長度 822，前50個：MBLXGXNLNBMYMLHBBBBBXBGLHJDNINBBBBLXPXOZTYUCANVNBN
# Ballet_13.csv latent 數量: 8
# Ballet_13.csv → 符號長度 8，前50個：HBAEGDFC
# Ballet_14.csv latent 數量: 1157
# Ballet_14.csv → 符號長度 1157，前50個：BQJJKJYBBBBBBBBBBBBBKQBCXQBBBBBZXBBBYJBQYJXJJJJKEY
# Ballet_16.csv latent 數量: 38
# Ballet_16.csv → 符號長度 38，前50個：BYYYBHBYYYYYVHQHZXCKRDWDFOMILJAPTUSEGN
# Ballet_17.csv latent 數量: 471
# Ballet_17.csv → 符號長度 471，前50個：WVVBPETXGQUCYMHOSFNDLWVBJAZBPETXGQUCYMHOSISSNDLDLS
# Ballet_18.csv latent 數量: 51
# Ballet_18.csv → 符號長度 51，前50個：HMMHMMHHMHCYBHHCYMZMHHXMQSWPOJVTIUKRHCMBCYBAGMEDFN
# Ballet_19.csv latent 數量: 219
# Ballet_19.csv → 符號長度 219，前50個：GBBBFFVVWRHHGTFVFWRVVWQYYVVDRUHNTZNXHACBTPARWRWTWN
# Ballet_2.csv latent 數量: 5
# Ballet_2.csv → 符號長度 5，前50個：CAEDB
# Ballet_20.csv latent 數量: 45
# Ballet_20.csv → 符號長度 45，前50個：ATEQEQEIUVBMCGXRKOCHPDLJJFFIUBBVCMCZWNKOLDLSY
# Ballet_21.csv latent 數量: 214
# Ballet_21.csv → 符號長度 214，前50個：MDMDMDMDMDMDMDCIMIZZXDMDMDMDMDMDMDMDMHDUDBJBJMJFRI
# Ballet_22.csv latent 數量: 359
# Ballet_22.csv → 符號長度 359，前50個：RHCPZAKAKWPLFWGLFVMOXUKOGBSOIIQWGPQAHKPYNSETPWGLZP
# Ballet_23.csv latent 數量: 69
# Ballet_23.csv → 符號長度 69，前50個：NCUTCETEUDEBIBCXNCXOGMQWEWEEEEEEUDEVVBVVVVVVVBEAAA
# Ballet_24.csv latent 數量: 309
# Ballet_24.csv → 符號長度 309，前50個：HVDVCBVJIWFKAKUDVCHVCUCCCCCODCCHCHUCHOHADYRARARAKG
# Ballet_25.csv latent 數量: 145
# Ballet_25.csv → 符號長度 145，前50個：EXUOOBXLXLWIWHAHDYHHHBZBVVXNXBOMRLLHBXOXBOWIXHFLFH
# Ballet_26.csv latent 數量: 161
# Ballet_26.csv → 符號長度 161，前50個：RCCRRRCLRCACLRCAPCPAPLBLEACNYSUHOPZTLECQCPRCLGLIFK
# Ballet_27.csv latent 數量: 15
# Ballet_27.csv → 符號長度 15，前50個：IGEFOAMNCKJDHLB
# Ballet_28.csv latent 數量: 69
# Ballet_28.csv → 符號長度 69，前50個：JTDZPWKRNNTDJBCUCSKGNOQFLGPXQJBCPXKGBCHILIYUPMVABC
# Ballet_29.csv latent 數量: 1273
# Ballet_29.csv → 符號長度 1273，前50個：EQTXZTQVQLXQGXQGTQVTXVEBQOOOVOQVQVVQVQXSGVASVSAIQZ
# Ballet_3.csv latent 數量: 1822
# Ballet_3.csv → 符號長度 1822，前50個：WAOJOAOWOIONINYVIIYSHXCXXXGAREXCXUUUMPGPGUMPMLUUUU
# Ballet_30.csv latent 數量: 573
# Ballet_30.csv → 符號長度 573，前50個：YPYNJJRRRKSPLLLSSSISSAAAAAAAAAAAAASSEEYJPPRRKCCJSS
# Ballet_31.csv latent 數量: 379
# Ballet_31.csv → 符號長度 379，前50個：EPDEPKICGDOTOOFKHCOOHFHFFOOOOODEQMFDOTSHFKKKTSOKKK
# Ballet_32.csv latent 數量: 544
# Ballet_32.csv → 符號長度 544，前50個：XPQTVYXZAXEJOJMJGMHPHKHHHFHXKHKXKDNFSBAIETOGLIPLGL
# Ballet_33.csv latent 數量: 172
# Ballet_33.csv → 符號長度 172，前50個：BBCIGICBGTKQWNIRCYILCCCCJECRJJICLGIILJIILBGICCCJCI
# Ballet_34.csv latent 數量: 76
# Ballet_34.csv → 符號長度 76，前50個：FVTDDSHRDCGJGYOGPEETAZNMUQCGBBDICBDDCBBDIIKDCCBJGB
# Ballet_35.csv latent 數量: 68
# Ballet_35.csv → 符號長度 68，前50個：TTWRBHDJJDJJDBJDMMMMMQHHRFUHQHREVCTMMPZYIRGJSLAIEX
# Ballet_36.csv latent 數量: 437
# Ballet_36.csv → 符號長度 437，前50個：ZPZTKWJIJXXDWUFESKWOIZPZFVWVFKSVBKBESQQIHQGZZSFCPC
# Ballet_37.csv latent 數量: 337
# Ballet_37.csv → 符號長度 337，前50個：NTNNNNXADWXANUTJYANAAAAAAAJAJAJJAHLDQHRHLBQNCNCTBJ
# Ballet_38.csv latent 數量: 66
# Ballet_38.csv → 符號長度 66，前50個：JEFQRXGKBBPBAMDMAPPAICAOHSLUYVZNAMPAAGKGKGATWTWTMA
# Ballet_39.csv latent 數量: 157
# Ballet_39.csv → 符號長度 157，前50個：MIUMHUMDXXXXHJEPZZEPBEPBZEXXHJJPJZEPZZEZZEIIPPZEPX
# Ballet_4.csv latent 數量: 48
# Ballet_4.csv → 符號長度 48，前50個：CTUSBNYLIUTGFXQIVKWNOLIMEGFEAFTGTEAGTGTGTCRZPDJH
# Ballet_40.csv latent 數量: 583
# Ballet_40.csv → 符號長度 583，前50個：TBTOYBTYNQFWHYNYIYENNRIOCGCCTOBTOTOTWBTYMQFTORBOLF
# Ballet_41.csv latent 數量: 625
# Ballet_41.csv → 符號長度 625，前50個：LCLAHPCHPDDMUZXSDVDIYYFFOQPCLAHPHSNDDMUZWSVDDRYAFF
# Ballet_42.csv latent 數量: 65
# Ballet_42.csv → 符號長度 65，前50個：RNULJMTQYVDIDHHHHHOKBZEEEPGWFAWFFAWFAFWFAWFAFAFCCC
# Ballet_43.csv latent 數量: 2856
# Ballet_43.csv → 符號長度 2856，前50個：LYWIHVBXHVOVYMYGKSWJLWDTWIYXDAOMFSKSSKSSKSWKSWKDSS
# Ballet_44.csv latent 數量: 17
# Ballet_44.csv → 符號長度 17，前50個：CKOMPEAQGFHNIBLJD
# Ballet_45.csv latent 數量: 811
# Ballet_45.csv → 符號長度 811，前50個：EGDEGDEDGDUXNXDVVDVVVVVVHBNIIOOLPZTIKOLKFLKFQQPZTF
# Ballet_46.csv latent 數量: 112
# Ballet_46.csv → 符號長度 112，前50個：OFDWELMJKZWRNDXQCISYVGHUPBBBTWEDHBBDHBBBBBBBBBBBDE
# Ballet_47.csv latent 數量: 2827
# Ballet_47.csv → 符號長度 2827，前50個：ZIIIIIIIIIIIIIMMHMDVQGHSJHWWWGDZSIZJISIIQQQUSUQDUF
# Ballet_48.csv latent 數量: 358
# Ballet_48.csv → 符號長度 358，前50個：NILLYPBLRWVTZWFBLAZPKKPKKCRKCEKWFBLDZJSCESWPKURKCC
# Ballet_5.csv latent 數量: 1676
# Ballet_5.csv → 符號長度 1676，前50個：XXQXHXHHXHXXXXQQXXHXHXHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# Ballet_6.csv latent 數量: 302
# Ballet_6.csv → 符號長度 302，前50個：QPMPPOCCCVWURFFYDDDIIGQQPPPPBOCLOVCCCFHYDDDIIGQQPP
# Ballet_7.csv latent 數量: 273
# Ballet_7.csv → 符號長度 273，前50個：FFFPPFFFFFFFFFFFFFFFFFFFFFFFFFFFFDFFDFDDDDDDDDDDDD
# Ballet_8.csv latent 數量: 714
# Ballet_8.csv → 符號長度 714，前50個：UNNWRRWLCJYYEEAKOTTPFGGHUDNRWWRWLJYYEEAKOTOSSIIGMG
# Ballet_9.csv latent 數量: 9
# Ballet_9.csv → 符號長度 9，前50個：CGEAFIDBH
# JiaJiangDance_49.csv latent 數量: 98
# JiaJiangDance_49.csv → 符號長度 98，前50個：DYUZCHVKCJGJCJICJCVGCVQINJNPHMGEBJIEPBGHQQQYQBWHSV
# JiaJiangDance_50.csv latent 數量: 8
# JiaJiangDance_50.csv → 符號長度 8，前50個：CEAGFDBH
# JiaJiangDance_51.csv latent 數量: 128
# JiaJiangDance_51.csv → 符號長度 128，前50個：DROMXPRZAPSVNSDFVGVGSKKRJVQVIKISIGSGVKVKSGIRIKGKVK
# JiaJiangDance_52.csv latent 數量: 54
# JiaJiangDance_52.csv → 符號長度 54，前50個：PFVPCKRSOIJYFDYZXWRNMQBPGPHIBVVPLTOPRFDDFGPEUAEUBO
# JiaJiangDance_53.csv latent 數量: 149
# JiaJiangDance_53.csv → 符號長度 149，前50個：HFHCRADBNPLOMAAYASHXHSHFHRHQBVBBMRPJFABIUHTIDLFLHS
# JiaJiangDance_54.csv latent 數量: 35
# JiaJiangDance_54.csv → 符號長度 35，前50個：UGHMIZXPVYWDCAIERTSIQEONFFAFLCJKBDD
# JiaJiangDance_55.csv latent 數量: 100
# JiaJiangDance_55.csv → 符號長度 100，前50個：QCHEIJKRGLZJKRLGNENLEYKROJLMGLMGLEGLEOSRGLBLBONFBG
# JiaJiangDance_56.csv latent 數量: 9
# JiaJiangDance_56.csv → 符號長度 9，前50個：HCEAGFBID
# JiaJiangDance_57.csv latent 數量: 574
# JiaJiangDance_57.csv → 符號長度 574，前50個：RCIJCIJSWCCWCWCWDYAWYYFYFHWHDHCHFHYHYYHAWSWDCWDWDD
# JiaJiangDance_58.csv latent 數量: 82
# JiaJiangDance_58.csv → 符號長度 82，前50個：BKGNVMQOFMSXJGKHQUUBIMSXJGKHDCUQBEJEDEQWJLTECRIYZE
# JiaJiangDance_59.csv latent 數量: 3
# JiaJiangDance_59.csv → 符號長度 3，前50個：BAC
# JiaJiangDance_60.csv latent 數量: 93
# JiaJiangDance_60.csv → 符號長度 93，前50個：FJNEYFGBHGQGQHCGCCGLGQHQBHNSGHNKGQNGQHVBLDQHVGYHGB
# JiaJiangDance_61.csv latent 數量: 182
# JiaJiangDance_61.csv → 符號長度 182，前50個：CNNNFBMMMMFCZLDEDTRFBJLQJIZULUGZUDLIVOTMUGEODNCNGA
# JiaJiangDance_62.csv latent 數量: 198
# JiaJiangDance_62.csv → 符號長度 198，前50個：EYDUOQBZMLBLFZLHMDQHGNKLFFFLVKBQTXGRPLFRFLKOVPRPHW
# JiaJiangDance_63.csv latent 數量: 275
# JiaJiangDance_63.csv → 符號長度 275，前50個：GGGGGGGQTUTOGGGQGTGTGQOIUKQVFCBKBCTCUZNSSSQSCUSSSQ
# JiaJiangDance_64.csv latent 數量: 266
# JiaJiangDance_64.csv → 符號長度 266，前50個：YYYYYAGTJGGCQZEVSVBMUKNRLCQXEVJGZGCYGGGGJGGGGGGGGJ
# JiaJiangDance_65.csv latent 數量: 299
# JiaJiangDance_65.csv → 符號長度 299，前50個：JBHJJJCJJJJJJJCJJHJBJJJJJJJJJJJJJJJJJJJJJJJJJJJJJH
# JiaJiangDance_66.csv latent 數量: 810
# JiaJiangDance_66.csv → 符號長度 810，前50個：IIISISSSSSSRDNZZODWLCLBGCIORORJJJKKKKKWCISSSSSISSS
# JiaJiangDance_67.csv latent 數量: 1451
# JiaJiangDance_67.csv → 符號長度 1451，前50個：NIRYIMEYWYMRYENUMHVYIXUHRADJGFWDDWDOWDIHDAGEHHDDTF
# JiaJiangDance_68.csv latent 數量: 195
# JiaJiangDance_68.csv → 符號長度 195，前50個：YLOGRGCDRGRGCDSRGCHORCRHOYRRYCHOGILFOYGXXMRMCMPOYW
# JiaJiangDance_69.csv latent 數量: 176
# JiaJiangDance_69.csv → 符號長度 176，前50個：CGWDLWGWLWGCLWGWGWGDFWGSFKMDWAMJUHRIEPDGEFFLSSFBED
# JiaJiangDance_70.csv latent 數量: 195
# JiaJiangDance_70.csv → 符號長度 195，前50個：DLDNQDNQGNDHASYFGNDHMFMFFXXXLGLLOGLSWCECCFMFFCLXLX
# JiaJiangDance_71.csv latent 數量: 173
# JiaJiangDance_71.csv → 符號長度 173，前50個：MMSBHBBMBKMKBQMKMHKYHKYCGYJKBUSBBKYCKUESBUSBBKMKYH
# JiaJiangDance_72.csv latent 數量: 195
# JiaJiangDance_72.csv → 符號長度 195，前50個：DLDDMDMDLDLDLDLDDMDDMDLHFHZMHARAFJIUVTMZMHDMDLHAFV
# JiaJiangDance_73.csv latent 數量: 254
# JiaJiangDance_73.csv → 符號長度 254，前50個：NDNHDADNEDDDAHDADNDTNDDDYBHNEFVQKUXGPTGOGUKPUGROAR
# JiaJiangDance_74.csv latent 數量: 485
# JiaJiangDance_74.csv → 符號長度 485，前50個：PLJPQAOFPNIFHGFAAACAPTATDFATAANFAFDDFHDTPHTTTHGOFM
# StreetDance_251.csv latent 數量: 1399
# StreetDance_251.csv → 符號長度 1399，前50個：NRGAMRNOZIRERRGRRRRRRRSERGTODWOURQUHQHHRRRRRRKKKKK
# StreetDance_75.csv latent 數量: 3129
# StreetDance_75.csv → 符號長度 3129，前50個：XFZMEGVBDFXHZOSTSEGTGSTMTEJFTXQOJEGOOWEJQWHACTIHLI
# StreetDance_76.csv latent 數量: 2647
# StreetDance_76.csv → 符號長度 2647，前50個：VYNZINIJYSSSSSSSSSSSSNFNBNNFBBBMNPIIIXQFDMOCLDGVRV
# StreetDance_77.csv latent 數量: 551
# StreetDance_77.csv → 符號長度 551，前50個：EVTHAVGTTTZZABBFFCUUUXUUUUUAMMCCCCMLMMMMMMMMMMMMML
# StreetDance_78.csv latent 數量: 350
# StreetDance_78.csv → 符號長度 350，前50個：ATUAUUAUUUUUUUUUUUUUUUUGUUUUUIAJQVADJEMIHEJEXALJOA
# StreetDance_79.csv latent 數量: 322
# StreetDance_79.csv → 符號長度 322，前50個：FHPKFPNUDPXHNKPRPVBPFSMNCMPESPKLNHGBPFSPKPNHDKYSHK
# StreetDance_80.csv latent 數量: 304
# StreetDance_80.csv → 符號長度 304，前50個：EFBGEOEJFYBZQOOYZQTRWTWQDOKMHRZRUEOWDLZWXGGDHCRMLP
# StreetDance_81.csv latent 數量: 81
# StreetDance_81.csv → 符號長度 81，前50個：YDDWDSLDSLQBQBQQLQBPFMXZTOAZGUQWKFLPBQZJTIJVTSJHTR
# StreetDance_82.csv latent 數量: 279
# StreetDance_82.csv → 符號長度 279，前50個：GQAGJGPCHIDFJGQRBMLFROIWFIUJGPKFKGQRTDDIIULQFKLDRF
# StreetDance_83.csv latent 數量: 339
# StreetDance_83.csv → 符號長度 339，前50個：YQRTGLRUPVLXTVCVXPXTPXRKLUXFXOVSANMDUAKXGLQBYDQWUC
# StreetDance_84.csv latent 數量: 154
# StreetDance_84.csv → 符號長度 154，前50個：FGTWYCWKQDEMBYLJGCWPJAVDTUPBDEUBVLGSHXIJAZCNKDRBVR
# StreetDance_85.csv latent 數量: 1739
# StreetDance_85.csv → 符號長度 1739，前50個：AWMCKWKSZJNCABKBWUHHUHJAELVOXYIAVGYVVWWUHHJELLONBI
# StreetDance_86.csv latent 數量: 98
# StreetDance_86.csv → 符號長度 98，前50個：JLWTOPXZKXVQUFINSDWGCAZEAKLAKMMEMEMKLMEOKMAMMMKBZE
# StreetDance_87.csv latent 數量: 1040
# StreetDance_87.csv → 符號長度 1040，前50個：CGRIFGGRPROVAWGWSWWZVCVRAAAAAKKKKKAKKKKKKKKKKKKXOP
# StreetDance_88.csv latent 數量: 5943
# StreetDance_88.csv → 符號長度 5943，前50個：AGKWXEEOINGNNNJMKWDEEBIGHMEHMCJNYVJRTUAQEQMOMEMHEH
# StreetDance_89.csv latent 數量: 2116
# StreetDance_89.csv → 符號長度 2116，前50個：VJJYPOOLYFYHXPGGGGGGGGGGFGGGGGGGGGGGGGGGGGGGGGGGGG
# StreetDance_90.csv latent 數量: 1323
# TaiwaneseAboriginalDance_169.csv → 符號長度 274，前50個：YJZJKHTZKMOIDZJREKAOODYVDJJJKGHODZCVHVOEVILPHIDJAG
# TaiwaneseAboriginalDance_170.csv latent 數量: 16
# TaiwaneseAboriginalDance_170.csv → 符號長度 16，前50個：DCBOPAJGEKFILMHN
# TaiwaneseAboriginalDance_171.csv latent 數量: 2
# TaiwaneseAboriginalDance_171.csv → 符號長度 2，前50個：AB
# TaiwaneseAboriginalDance_172.csv latent 數量: 261
# TaiwaneseAboriginalDance_172.csv → 符號長度 261，前50個：NNUNGOZTWCYWCADSAEHVYQCEBNEUSEDNUNGCKNNEEVTTVEEYBA
# TaiwaneseAboriginalDance_173.csv latent 數量: 12
# TaiwaneseAboriginalDance_173.csv → 符號長度 12，前50個：GJEFAKHBIDCL
# TaiwaneseAboriginalDance_174.csv latent 數量: 687
# TaiwaneseAboriginalDance_174.csv → 符號長度 687，前50個：WDBFEIBEDNJFRDZZZIZZZAAYNCENDRERCDNDFNJIFRIEOWCBFE
# TaiwaneseAboriginalDance_175.csv latent 數量: 1373
# TaiwaneseAboriginalDance_175.csv → 符號長度 1373，前50個：GGGLGGKGCGGOGTEHBSSOSYHDLIHDFNOQNIEDLIXFNGGTGBQUTX
# TaiwaneseAboriginalDance_176.csv latent 數量: 21
# TaiwaneseAboriginalDance_176.csv → 符號長度 21，前50個：GMPUTNEAQRSLOIKJFHBDC
# TaiwaneseAboriginalDance_177.csv latent 數量: 515
# TaiwaneseAboriginalDance_177.csv → 符號長度 515，前50個：BLBLFRBBXSQAQWYICOFHXPUBELQDLIHLFHUXJUWYRCOUHXPCFY
# TaiwaneseAboriginalDance_178.csv latent 數量: 180
# TaiwaneseAboriginalDance_178.csv → 符號長度 180，前50個：TENAELNTTETTTTTTTTETTTTTTTETETTELRETJDNEXKRFKWHNRR
# TaiwaneseAboriginalDance_179.csv latent 數量: 661
# TaiwaneseAboriginalDance_179.csv → 符號長度 661，前50個：FFBXSBUXHGQLYZOLVRBFSVBMFLBFFFFBBFBSYWLHKKWMRMRDXS
# TaiwaneseAboriginalDance_180.csv latent 數量: 4568
# TaiwaneseAboriginalDance_180.csv → 符號長度 4568，前50個：FUJJJWIWCIWCHDRBDWLRDFDQIQWUJCJWDVCRHFKSKZRUCATYNB
# TaiwaneseAboriginalDance_181.csv latent 數量: 225
# TaiwaneseAboriginalDance_181.csv → 符號長度 225，前50個：QXYJMUDIMEXLXLLLCNRNRCNNRCGSIDUNUZUAFPWLDENUZRXZDX
# TaiwaneseAboriginalDance_182.csv latent 數量: 134
# TaiwaneseAboriginalDance_182.csv → 符號長度 134，前50個：BNXIQOUQLRESLNWWMBJKCSNIWJJEWJJBCGJRCCGRGDDLMWWJBC
# TaiwaneseAboriginalDance_183.csv latent 數量: 9
# TaiwaneseAboriginalDance_183.csv → 符號長度 9，前50個：GEHACBFDI
# TaiwaneseAboriginalDance_184.csv latent 數量: 2438
# TaiwaneseAboriginalDance_184.csv → 符號長度 2438，前50個：CWLVUYEWPKNRHTFSWKFIMXPRVWTFVKRVSOYWFFJBLYHTCLMWAF
# TaiwaneseAboriginalDance_185.csv latent 數量: 13
# TaiwaneseAboriginalDance_185.csv → 符號長度 13，前50個：CKEGAJMFDHILB
# TaiwaneseAboriginalDance_186.csv latent 數量: 15
# TaiwaneseAboriginalDance_186.csv → 符號長度 15，前50個：CIMLEAGFHDBOKNJ
# TaiwaneseAboriginalDance_187.csv latent 數量: 2360
# TaiwaneseAboriginalDance_187.csv → 符號長度 2360，前50個：GOLJXZBTJSYWAGZPGGWEPLPKCRHYOACDIYQABQKBXQGTJBWAWJ
# TaiwaneseAboriginalDance_188.csv latent 數量: 21
# TaiwaneseAboriginalDance_188.csv → 符號長度 21，前50個：GPQMJFTASRUEKICLHNODB
# TaiwaneseAboriginalDance_189.csv latent 數量: 93
# TaiwaneseAboriginalDance_189.csv → 符號長度 93，前50個：GBDBJJMHCMKOKUKXDXHKFGJUKHEWXFEHINAZFGXBDOMDJOOOOO
# TaiwaneseAboriginalDance_190.csv latent 數量: 5910
# TaiwaneseAboriginalDance_190.csv → 符號長度 5910，前50個：CPICRFGIUZSHZRDPDWKFPWPWYYYYYYOYYYYYYYYYYYYLFGCGEY
# TaiwaneseAboriginalDance_191.csv latent 數量: 8053
# TaiwaneseAboriginalDance_191.csv → 符號長度 8053，前50個：XWCCVSBASAQQXWINLOGTVBRVBYXNNNTOFRVOGXVPTVHUJRAGTI
# TaiwaneseAboriginalDance_192.csv latent 數量: 2417
# TaiwaneseAboriginalDance_192.csv → 符號長度 2417，前50個：PKCKAZQXWOPRFGCDUDYNNNNNNNHNTRRCRDDZZVNNNQWRSTSQSQ
# TaiwaneseAboriginalDance_193.csv latent 數量: 1579
# TaiwaneseAboriginalDance_193.csv → 符號長度 1579，前50個：AOXWXDWIGYEGOSLKMODZMDQSRSDNNDNKQKQKQKNKMKNKNKKZNK
# TaiwaneseAboriginalDance_194.csv latent 數量: 80
# TaiwaneseAboriginalDance_194.csv → 符號長度 80，前50個：YUTHBVFDAEISEPIWMLGVIZFNAHDQGKHKEPPKVKKOQJSEBRCEIA
# TaiwaneseAboriginalDance_195.csv latent 數量: 557
# TaiwaneseAboriginalDance_195.csv → 符號長度 557，前50個：XSGLWZFPEZJCAPFWJKCOBMXRNAPHLSASTPFMBDJCULQIPUDQMU
# TaiwaneseAboriginalDance_196.csv latent 數量: 2618
# TaiwaneseAboriginalDance_196.csv → 符號長度 2618，前50個：ULZDDLISFZTMTEVTFAPMJFQGHYBJAPDMAECSBYCSKBKIKDNAFC
# TaiwaneseAboriginalDance_197.csv latent 數量: 4
# TaiwaneseAboriginalDance_197.csv → 符號長度 4，前50個：CABD
# TaiwaneseAboriginalDance_198.csv latent 數量: 1168
# TaiwaneseAboriginalDance_198.csv → 符號長度 1168，前50個：QIPCHLOFQFERSEGKVPNVZUIFXICIEXIWSKSLRTWUIFXUBMLUID
# TaiwaneseAboriginalDance_199.csv latent 數量: 5337
# TaiwaneseAboriginalDance_199.csv → 符號長度 5337，前50個：IOWNJSCWFZEXZOBEZSHFYECJBDZEPLEDYACOIWNHZHTFJEOZRX
# TaiwaneseAboriginalDance_200.csv latent 數量: 1858
# TaiwaneseAboriginalDance_200.csv → 符號長度 1858，前50個：YQKQFCZBFQFOPNLPWVCGYOIQOHSLLKCSUOICYLFIPLVWEWEJXK
# TaiwaneseAboriginalDance_201.csv latent 數量: 32
# TaiwaneseAboriginalDance_201.csv → 符號長度 32，前50個：PNGKLDQXWSSCUZIJEHVOMEHRTBAFFCYY
# TaiwaneseAboriginalDance_202.csv latent 數量: 185
# TaiwaneseAboriginalDance_202.csv → 符號長度 185，前50個：OHYUGOKFJEMZEEIMAFMZPQHVZSHBSGOOGZVJDDXJEDDXOGZQMT
# TaiwaneseAboriginalDance_203.csv latent 數量: 2352
# TaiwaneseAboriginalDance_203.csv → 符號長度 2352，前50個：ZJIMPZCHCROELBRSYTHZAVGZWEPFVBXWUEUOWZGQEBGFIGOFJS
# TaiwaneseAboriginalDance_204.csv latent 數量: 26
# TaiwaneseAboriginalDance_204.csv → 符號長度 26，前50個：GFDHMPKOIAYEZXUTCLBRVWNQJS
# TaiwaneseAboriginalDance_205.csv latent 數量: 892
# TaiwaneseAboriginalDance_205.csv → 符號長度 892，前50個：QFTLMQFMSXWKXGGJVRRCCFAQVVZICFAAAMMSWSEWGJJSZLCBSM
# TaiwaneseAboriginalDance_206.csv latent 數量: 766
# TaiwaneseAboriginalDance_206.csv → 符號長度 766，前50個：VPAHEEELLLHFZUOZFZFLHLKYVYNYXNNXNGNRTLLLLLLLZZLZVN
# TaiwaneseAboriginalDance_207.csv latent 數量: 7161
# TaiwaneseAboriginalDance_207.csv → 符號長度 7161，前50個：YQQQQBBDFDMMSUVIVXSKVPTNCSTAGIGXOKXXYQYDQAUUUVDODD
# TaiwaneseAboriginalDance_208.csv latent 數量: 6982
# TaiwaneseAboriginalDance_208.csv → 符號長度 6982，前50個：DZEEEAEAASFHMMRFLXXFRSNDQOOKUVJUUUUUEAAEAFXWXFRCDX
# TaiwaneseAboriginalDance_209.csv latent 數量: 1954
# TaiwaneseAboriginalDance_209.csv → 符號長度 1954，前50個：LWESKKOHSBGSBGSDLXDTEVMRUJRUDODODJJDPHGPXPIICXIXWC
# TaiwaneseAboriginalDance_210.csv latent 數量: 1375
# TaiwaneseAboriginalDance_210.csv → 符號長度 1375，前50個：UURNWWKCAYYORAWAJPPMJPPPJPJPPLLQLGLQQQLLQUQLUNBGUU
# TaiwaneseAboriginalDance_211.csv latent 數量: 5
# TaiwaneseAboriginalDance_211.csv → 符號長度 5，前50個：CADBE
# TaiwaneseAboriginalDance_212.csv latent 數量: 1962
# TaiwaneseAboriginalDance_212.csv → 符號長度 1962，前50個：PPPNGNZNZKZKXRTIEPNVNBABAABABMBYYYMDXXXIIEXLTAJIIP
# TaiwaneseAboriginalDance_213.csv latent 數量: 2157
# TaiwaneseAboriginalDance_213.csv → 符號長度 2157，前50個：TGICNTRFXMHNRRFGVCCJJBVVWWJEESEZOIZIIUNDDDZZZZDZZZ
# TaiwaneseAboriginalDance_214.csv latent 數量: 3537
# TaiwaneseAboriginalDance_214.csv → 符號長度 3537，前50個：LGCIIFLVMXXSSSPPPGWRZFEAHHCBQQQQQQQQFQNNNNNNQQFQQQ
# TaiwaneseAboriginalDance_215.csv latent 數量: 1375
# TaiwaneseAboriginalDance_215.csv → 符號長度 1375，前50個：EDEOOOOKKQNEYENEOEOBKKQQQTATMDIUMPRRQMMLMULSRHPRPR
# TaiwaneseAboriginalDance_216.csv latent 數量: 1959
# TaiwaneseAboriginalDance_216.csv → 符號長度 1959，前50個：UWZUKHPOYRNOIIIIDIAJYYXKQQQMGXWJXKMQDMJDWJHVOYFYXK
# TaiwaneseAboriginalDance_217.csv latent 數量: 6116
# TaiwaneseAboriginalDance_217.csv → 符號長度 6116，前50個：QRDCIBIDIUAVAZEZQOFEPNQFPBKJWXWNDDDDEPBDDIRUNHPBLK
# TaiwaneseAboriginalDance_218.csv latent 數量: 1393
# TaiwaneseAboriginalDance_218.csv → 符號長度 1393，前50個：JTDYZZZIMIMSMSMZZZZTTTTTTTTTMTTTTLTTTMTTTTTRLTNTTE
# TaiwaneseAboriginalDance_219.csv latent 數量: 207
# TaiwaneseAboriginalDance_219.csv → 符號長度 207，前50個：TQZIYRTGDRTEERAMMKKCHHHHCFEMTKCHJELEZGYRTGDNDNDFJB
# TaiwaneseAboriginalDance_220.csv latent 數量: 1336
# TaiwaneseAboriginalDance_220.csv → 符號長度 1336，前50個：MWEGMIQIMIMIMMIMIMGMIGTMEGMMJLCMAXMEMIRMIMIATFGGMF
# TaiwaneseAboriginalDance_221.csv latent 數量: 507
# TaiwaneseAboriginalDance_221.csv → 符號長度 507，前50個：GPRHASPOPXNGUUIYYYDOVYBKBKPVXMPRUJYUKBWWUZUUZZZLZS
# TaiwaneseAboriginalDance_222.csv latent 數量: 45
# TaiwaneseAboriginalDance_222.csv → 符號長度 45，前50個：IYDVZBBBEEGCEGCEWGCBNNNNAGCARYEGPUXFKTQLOJMHS
# TaiwaneseAboriginalDance_223.csv latent 數量: 131
# TaiwaneseAboriginalDance_223.csv → 符號長度 131，前50個：NIFOGMUSLABAKAKAKYHRRKYNFFGGGSSSIRRJYSNHFGGBAHRRJY
# TaiwaneseAboriginalDance_224.csv latent 數量: 481
# TaiwaneseAboriginalDance_224.csv → 符號長度 481，前50個：AKNDLIGFIHTRYTKIDLWHEJHTQQCMUQCBULQJVFIANGFPKNKUGY
# TaiwaneseAboriginalDance_225.csv latent 數量: 28
# TaiwaneseAboriginalDance_225.csv → 符號長度 28，前50個：QONCYLSPGMHJKIVUDTZWXEBAFBRF
# TaiwaneseAboriginalDance_226.csv latent 數量: 111
# TaiwaneseAboriginalDance_226.csv → 符號長度 111，前50個：PZJBMUDRIDFWQOKSHHLKLLKLHBLLZKHLBAVBHHHLLAZBBZKZZK
# TaiwaneseAboriginalDance_227.csv latent 數量: 1576
# TaiwaneseAboriginalDance_227.csv → 符號長度 1576，前50個：ZBDRDMCNMBBBLVIBBZBUCNGRXEEKOFCMKDZEOOOOOBBBBBBBBB
# TaiwaneseAboriginalDance_228.csv latent 數量: 237
# TaiwaneseAboriginalDance_228.csv → 符號長度 237，前50個：DIBIBIBCTZTCTCFCFFFFFFFZFHTZFBUCTIJRMCPSHHZAXAZTZT
# TaiwaneseAboriginalDance_229.csv latent 數量: 559
# TaiwaneseAboriginalDance_229.csv → 符號長度 559，前50個：APNXVIBIXVRHRFGGWWXNTGUMNXVTVNACTABAMPEZDIDRSRKJQN
# TaiwaneseAboriginalDance_230.csv latent 數量: 97
# TaiwaneseAboriginalDance_230.csv → 符號長度 97，前50個：PUGMEOJDJHBSHXJJYSWVZBIRKFNQLLEQABXSABSHAJKPNALLSH
# TaiwaneseAboriginalDance_231.csv latent 數量: 1015
# TaiwaneseAboriginalDance_231.csv → 符號長度 1015，前50個：DJPWYTSNPEJPUJPTMLVSAPPTRQJQHLHJNJNJJJPPTRJJNEQSPE
# TaiwaneseAboriginalDance_232.csv latent 數量: 210
# TaiwaneseAboriginalDance_232.csv → 符號長度 210，前50個：DOWMLXNJZGRCHVYASNHKNDNHFHUNVNNVFUUNHUNUUUUUKNUUCQ
# TaiwaneseAboriginalDance_233.csv latent 數量: 530
# TaiwaneseAboriginalDance_233.csv → 符號長度 530，前50個：BBBBBBNBJEXCNQRNHHHHBTVJKPVLDCLLLHHHBBBBBBXJBBBTVT
# TaiwaneseAboriginalDance_234.csv latent 數量: 2737
# TaiwaneseAboriginalDance_234.csv → 符號長度 2737，前50個：ZVIFVFIIVIIGYFHYODYUPSXHCXIVFFXVFXAFINFMVYUDOUHOOH
# TaiwaneseAboriginalDance_235.csv latent 數量: 29
# TaiwaneseAboriginalDance_235.csv → 符號長度 29，前50個：RGHYSZQENIAMVJUBFXTPBFWKCOLDK
# TaiwaneseAboriginalDance_236.csv latent 數量: 4
# TaiwaneseAboriginalDance_236.csv → 符號長度 4，前50個：CABD
# TaiwaneseAboriginalDance_238.csv latent 數量: 290
# TaiwaneseAboriginalDance_238.csv → 符號長度 290，前50個：RCXXVXEVYBEJUUROURZJGUQDVHCWACMGVUGZDTFYQYQRQQHUUD
# TaiwaneseAboriginalDance_94.csv latent 數量: 1264
# TaiwaneseAboriginalDance_94.csv → 符號長度 1264，前50個：AEMJIRMMJRRBCMJLUDBUZKCZXLLEEABVHHVHVHHHVBLBBBBBBB
# TaiwaneseAboriginalDance_95.csv latent 數量: 1846
# TaiwaneseAboriginalDance_95.csv → 符號長度 1846，前50個：LLILLILJYVVBBTMJLLLLLLLLLLLLKJLLLLBBNNNNNNNNNNNNNN
# TaiwaneseAboriginalDance_96.csv latent 數量: 5553
# TaiwaneseAboriginalDance_96.csv → 符號長度 5553，前50個：SOJFSBHIHNHMTOCCTRRRRFFFFFFFTTTRDZOFFFFFFFFYTXPCJF
# ⚠️ TaiwaneseAboriginalDance_97.csv 長度不足，跳過
# TaiwaneseAboriginalDance_98.csv latent 數量: 6884
# TaiwaneseAboriginalDance_98.csv → 符號長度 6884，前50個：CCCCAUQQQKVXSOHEBTTVLSZSPLYLZHYOGOUMRNCICMUNGUNGRU
# TaiwaneseAboriginalDance_99.csv latent 數量: 40
# TaiwaneseAboriginalDance_99.csv → 符號長度 40，前50個：HQKMJRIGOTSZVYLBLCLBBCBLBLBBBXXXUWAEFDPN
# TapDance_239.csv latent 數量: 3571
# TapDance_239.csv → 符號長度 3571，前50個：GGYPGGGGYGGKPFGBNYXKFRIBVVELDTTHPBNAQAECGGGGGGGGGG
# TapDance_240.csv latent 數量: 1376
# TapDance_240.csv → 符號長度 1376，前50個：GGGGGGGGGGGGGGGGGGWGGGGGGGGGGGGGGGGGGGGGGGGGGGPPPP
# TapDance_241.csv latent 數量: 4768
# TapDance_241.csv → 符號長度 4768，前50個：DJFGFHXJFISFTBHPFGPHRUSUSEEEECLXBIXRRPQBZXBGVURWVE
# TapDance_242.csv latent 數量: 2697
# TapDance_242.csv → 符號長度 2697，前50個：SFJDBGGSZSJLCLEZZELLFUJDGGZFJDUJDTZECLSJETLNLSRQUJ
# TapDance_243.csv latent 數量: 4124
# TapDance_243.csv → 符號長度 4124，前50個：EEEEJJJJBJJJJJJJEEFFEJEJJEEJJJEEXXGGBKSSSSEEEEFFFF
# TapDance_244.csv latent 數量: 3788
# TapDance_244.csv → 符號長度 3788，前50個：FRWLFYOJBBBBBBBBBZNNNHHIITKTJIZIZIFBWBBFONXFIILFII
# TapDance_245.csv latent 數量: 3250
# TapDance_245.csv → 符號長度 3250，前50個：BVBSFKNKVJAMTSYYTOYGKJYQCLVDSITXKGVDSMGSKTOLQOLMQN
# TapDance_246.csv latent 數量: 3628
# TapDance_246.csv → 符號長度 3628，前50個：AQYAUFICQYQDQYQDJTRMHEEEFCPJLEMPHKPPUFYHEXUEHEJJYO
# TapDance_247.csv latent 數量: 3402
# TapDance_247.csv → 符號長度 3402，前50個：IIDDMDMDDDDMDMMDMMDMDIIIIIIIIIIIIIIIMIDMDDDDDDMDMM
# TapDance_248.csv latent 數量: 3302
# TapDance_248.csv → 符號長度 3302，前50個：PPPPPPPPPPPEPBPYPYOPYPFFFFYMHPIOPYPMHPINRNCEFFYBMB
# TapDance_249.csv latent 數量: 45
# TapDance_249.csv → 符號長度 45，前50個：ACMQLBRJDGPOUYWVRKIENBRJHEPTSXCLDGDZAMFLFCGDG
# TapDance_250.csv latent 數量: 3284
# TapDance_250.csv → 符號長度 3284，前50個：MMPLPPPPPCBVDKDLHOPGGEPEEPEEPEPVEPCEPEEGNKAFWTTTTT

# %%
# --- Step 7: 儲存 JSON ---
with open("symbol_sequences08.json", "w", encoding="utf-8") as f:
    json.dump(symbol_dict, f, indent=2, ensure_ascii=False)

print(f"✅ 已儲存 symbol_sequences08.json，共 {len(symbol_dict)} 段舞")
# Out:
# ✅ 已儲存 symbol_sequences08.json，共 246 段舞
