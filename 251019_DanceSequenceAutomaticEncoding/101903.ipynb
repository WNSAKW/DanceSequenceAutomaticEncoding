# %%
import os
import json
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler

# %%
# ============================================================
# 1️⃣ 與訓練時完全相同的模型定義
# ============================================================
class VectorQuantizer(nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.embedding_dim = embedding_dim
        self.num_embeddings = num_embeddings
        self.embedding = nn.Embedding(num_embeddings, embedding_dim)
        self.embedding.weight.data.uniform_(-1/num_embeddings, 1/num_embeddings)

    def forward(self, x):
        # x: (batch, latent_dim)
        distances = (
            torch.sum(x**2, dim=1, keepdim=True)
            + torch.sum(self.embedding.weight**2, dim=1)
            - 2 * torch.matmul(x, self.embedding.weight.t())
        )
        encoding_indices = torch.argmin(distances, dim=1)
        quantized = self.embedding(encoding_indices)
        return quantized, encoding_indices


class VQVAE(nn.Module):
    def __init__(self, input_dim=99, hidden_dim=128, latent_dim=32, num_embeddings=64):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, latent_dim)
        )
        self.vq = VectorQuantizer(num_embeddings, latent_dim)
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        z_q, indices = self.vq(z)
        x_recon = self.decoder(z_q)
        return x_recon, indices, z, z_q

# %%
# ============================================================
# 2️⃣ 載入訓練好的模型
# ============================================================
device = "cuda" if torch.cuda.is_available() else "cpu"
model = VQVAE().to(device)
state_dict = torch.load("vqvae_model.pth", map_location=device)
model.load_state_dict(state_dict)
model.eval()
print("✅ 模型已成功載入")
# Out:
# ✅ 模型已成功載入
# C:\Users\user\AppData\Local\Temp\ipykernel_6160\2535830407.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load("vqvae_model.pth", map_location=device)

# %%
# ============================================================
# 3️⃣ 定義 CSV → 骨架陣列轉換函式
# ============================================================
def parse_point(s):
    s = s.strip("()")
    parts = [float(p.strip(" '")) for p in s.split(",")]
    return parts

def csv_to_pose_array(csv_path):
    df = pd.read_csv(csv_path)
    pose_cols = [c for c in df.columns if c != "frame"]
    poses = []
    for _, row in df.iterrows():
        pose = []
        for c in pose_cols:
            pose += parse_point(row[c])
        poses.append(pose)
    return np.array(poses)  # (N_frames, 99)

# %%
# ============================================================
# 4️⃣ 處理資料夾中所有 CSV，轉成符號序列
# ============================================================
folder_path = "./dance_csv/"
output_json = "symbol_sequences.json"

symbol_dict = {}
scaler = StandardScaler()

for file_name in os.listdir(folder_path):
    if file_name.endswith(".csv"):
        file_path = os.path.join(folder_path, file_name)
        print(f"📄 處理中：{file_name}")

        # 讀取骨架資料
        poses = csv_to_pose_array(file_path)
        poses = scaler.fit_transform(poses)

        data = torch.tensor(poses, dtype=torch.float32).to(device)

        with torch.no_grad():
            _, indices, _, _ = model(data)
            indices = indices.cpu().numpy()

        # 轉成字母序列（A~Z 重複）
        symbols = [chr(65 + (i % 26)) for i in indices]
        symbol_seq = "".join(symbols)

        symbol_dict[file_name] = {
            "length": len(symbols),
            "symbols": symbol_seq
        }
# Out:
# 📄 處理中：Ballet_1.csv
# 📄 處理中：Ballet_10.csv
# 📄 處理中：Ballet_11.csv
# 📄 處理中：Ballet_12.csv
# 📄 處理中：Ballet_13.csv
# 📄 處理中：Ballet_14.csv
# 📄 處理中：Ballet_15.csv
# 📄 處理中：Ballet_16.csv
# 📄 處理中：Ballet_17.csv
# 📄 處理中：Ballet_18.csv
# 📄 處理中：Ballet_19.csv
# 📄 處理中：Ballet_2.csv
# 📄 處理中：Ballet_20.csv
# 📄 處理中：Ballet_21.csv
# 📄 處理中：Ballet_22.csv
# 📄 處理中：Ballet_23.csv
# 📄 處理中：Ballet_24.csv
# 📄 處理中：Ballet_25.csv
# 📄 處理中：Ballet_26.csv
# 📄 處理中：Ballet_27.csv
# 📄 處理中：Ballet_28.csv
# 📄 處理中：Ballet_29.csv
# 📄 處理中：Ballet_3.csv
# 📄 處理中：Ballet_30.csv
# 📄 處理中：Ballet_31.csv
# 📄 處理中：Ballet_32.csv
# 📄 處理中：Ballet_33.csv
# 📄 處理中：Ballet_34.csv
# 📄 處理中：Ballet_35.csv
# 📄 處理中：Ballet_36.csv
# 📄 處理中：Ballet_37.csv
# 📄 處理中：Ballet_38.csv
# 📄 處理中：Ballet_39.csv
# 📄 處理中：Ballet_4.csv
# 📄 處理中：Ballet_40.csv
# 📄 處理中：Ballet_41.csv
# 📄 處理中：Ballet_42.csv
# 📄 處理中：Ballet_43.csv
# 📄 處理中：Ballet_44.csv
# 📄 處理中：Ballet_45.csv
# 📄 處理中：Ballet_46.csv
# 📄 處理中：Ballet_47.csv
# 📄 處理中：Ballet_48.csv
# 📄 處理中：Ballet_5.csv
# 📄 處理中：Ballet_6.csv
# 📄 處理中：Ballet_7.csv
# 📄 處理中：Ballet_8.csv
# 📄 處理中：Ballet_9.csv
# 📄 處理中：JiaJiangDance_49.csv
# 📄 處理中：JiaJiangDance_50.csv
# 📄 處理中：JiaJiangDance_51.csv
# 📄 處理中：JiaJiangDance_52.csv
# 📄 處理中：JiaJiangDance_53.csv
# 📄 處理中：JiaJiangDance_54.csv
# 📄 處理中：JiaJiangDance_55.csv
# 📄 處理中：JiaJiangDance_56.csv
# 📄 處理中：JiaJiangDance_57.csv
# 📄 處理中：JiaJiangDance_58.csv
# 📄 處理中：JiaJiangDance_59.csv
# 📄 處理中：JiaJiangDance_60.csv
# 📄 處理中：JiaJiangDance_61.csv
# 📄 處理中：JiaJiangDance_62.csv
# 📄 處理中：JiaJiangDance_63.csv
# 📄 處理中：JiaJiangDance_64.csv
# 📄 處理中：JiaJiangDance_65.csv
# 📄 處理中：JiaJiangDance_66.csv
# 📄 處理中：JiaJiangDance_67.csv
# 📄 處理中：JiaJiangDance_68.csv
# 📄 處理中：JiaJiangDance_69.csv
# 📄 處理中：JiaJiangDance_70.csv
# 📄 處理中：JiaJiangDance_71.csv
# 📄 處理中：JiaJiangDance_72.csv
# 📄 處理中：JiaJiangDance_73.csv
# 📄 處理中：JiaJiangDance_74.csv
# 📄 處理中：StreetDance_251.csv
# 📄 處理中：StreetDance_75.csv
# 📄 處理中：StreetDance_76.csv
# 📄 處理中：StreetDance_77.csv
# 📄 處理中：StreetDance_78.csv
# 📄 處理中：StreetDance_79.csv
# 📄 處理中：StreetDance_80.csv
# 📄 處理中：StreetDance_81.csv
# 📄 處理中：StreetDance_82.csv
# 📄 處理中：StreetDance_83.csv
# 📄 處理中：StreetDance_84.csv
# 📄 處理中：StreetDance_85.csv
# 📄 處理中：StreetDance_86.csv
# 📄 處理中：StreetDance_87.csv
# 📄 處理中：StreetDance_88.csv
# 📄 處理中：StreetDance_89.csv
# 📄 處理中：StreetDance_90.csv
# 📄 處理中：StreetDance_91.csv
# 📄 處理中：StreetDance_92.csv
# 📄 處理中：StreetDance_93.csv
# 📄 處理中：TaiwaneseAboriginalDance_100.csv
# 📄 處理中：TaiwaneseAboriginalDance_101.csv
# 📄 處理中：TaiwaneseAboriginalDance_102.csv
# 📄 處理中：TaiwaneseAboriginalDance_103.csv
# 📄 處理中：TaiwaneseAboriginalDance_104.csv
# 📄 處理中：TaiwaneseAboriginalDance_105.csv
# 📄 處理中：TaiwaneseAboriginalDance_106.csv
# 📄 處理中：TaiwaneseAboriginalDance_107.csv
# 📄 處理中：TaiwaneseAboriginalDance_108.csv
# 📄 處理中：TaiwaneseAboriginalDance_109.csv
# 📄 處理中：TaiwaneseAboriginalDance_110.csv
# 📄 處理中：TaiwaneseAboriginalDance_111.csv
# 📄 處理中：TaiwaneseAboriginalDance_112.csv
# 📄 處理中：TaiwaneseAboriginalDance_113.csv
# 📄 處理中：TaiwaneseAboriginalDance_114.csv
# 📄 處理中：TaiwaneseAboriginalDance_115.csv
# 📄 處理中：TaiwaneseAboriginalDance_116.csv
# 📄 處理中：TaiwaneseAboriginalDance_117.csv
# 📄 處理中：TaiwaneseAboriginalDance_118.csv
# 📄 處理中：TaiwaneseAboriginalDance_119.csv
# 📄 處理中：TaiwaneseAboriginalDance_120.csv
# 📄 處理中：TaiwaneseAboriginalDance_121.csv
# 📄 處理中：TaiwaneseAboriginalDance_122.csv
# 📄 處理中：TaiwaneseAboriginalDance_123.csv
# 📄 處理中：TaiwaneseAboriginalDance_124.csv
# 📄 處理中：TaiwaneseAboriginalDance_125.csv
# 📄 處理中：TaiwaneseAboriginalDance_126.csv
# 📄 處理中：TaiwaneseAboriginalDance_127.csv
# 📄 處理中：TaiwaneseAboriginalDance_128.csv
# 📄 處理中：TaiwaneseAboriginalDance_129.csv
# 📄 處理中：TaiwaneseAboriginalDance_130.csv
# 📄 處理中：TaiwaneseAboriginalDance_131.csv
# 📄 處理中：TaiwaneseAboriginalDance_132.csv
# 📄 處理中：TaiwaneseAboriginalDance_133.csv
# 📄 處理中：TaiwaneseAboriginalDance_134.csv
# 📄 處理中：TaiwaneseAboriginalDance_135.csv
# 📄 處理中：TaiwaneseAboriginalDance_136.csv
# 📄 處理中：TaiwaneseAboriginalDance_137.csv
# 📄 處理中：TaiwaneseAboriginalDance_138.csv
# 📄 處理中：TaiwaneseAboriginalDance_139.csv
# 📄 處理中：TaiwaneseAboriginalDance_140.csv
# 📄 處理中：TaiwaneseAboriginalDance_141.csv
# 📄 處理中：TaiwaneseAboriginalDance_142.csv
# 📄 處理中：TaiwaneseAboriginalDance_143.csv
# 📄 處理中：TaiwaneseAboriginalDance_144.csv
# 📄 處理中：TaiwaneseAboriginalDance_145.csv
# 📄 處理中：TaiwaneseAboriginalDance_146.csv
# 📄 處理中：TaiwaneseAboriginalDance_147.csv
# 📄 處理中：TaiwaneseAboriginalDance_148.csv
# 📄 處理中：TaiwaneseAboriginalDance_149.csv
# 📄 處理中：TaiwaneseAboriginalDance_150.csv
# 📄 處理中：TaiwaneseAboriginalDance_151.csv
# 📄 處理中：TaiwaneseAboriginalDance_152.csv
# 📄 處理中：TaiwaneseAboriginalDance_153.csv
# 📄 處理中：TaiwaneseAboriginalDance_154.csv
# 📄 處理中：TaiwaneseAboriginalDance_155.csv
# 📄 處理中：TaiwaneseAboriginalDance_156.csv
# 📄 處理中：TaiwaneseAboriginalDance_157.csv
# 📄 處理中：TaiwaneseAboriginalDance_158.csv
# 📄 處理中：TaiwaneseAboriginalDance_159.csv
# 📄 處理中：TaiwaneseAboriginalDance_160.csv
# 📄 處理中：TaiwaneseAboriginalDance_161.csv
# 📄 處理中：TaiwaneseAboriginalDance_162.csv
# 📄 處理中：TaiwaneseAboriginalDance_163.csv
# 📄 處理中：TaiwaneseAboriginalDance_164.csv
# 📄 處理中：TaiwaneseAboriginalDance_165.csv
# 📄 處理中：TaiwaneseAboriginalDance_166.csv
# 📄 處理中：TaiwaneseAboriginalDance_167.csv
# 📄 處理中：TaiwaneseAboriginalDance_168.csv
# 📄 處理中：TaiwaneseAboriginalDance_169.csv
# 📄 處理中：TaiwaneseAboriginalDance_170.csv
# 📄 處理中：TaiwaneseAboriginalDance_171.csv
# 📄 處理中：TaiwaneseAboriginalDance_172.csv
# 📄 處理中：TaiwaneseAboriginalDance_173.csv
# 📄 處理中：TaiwaneseAboriginalDance_174.csv
# 📄 處理中：TaiwaneseAboriginalDance_175.csv
# 📄 處理中：TaiwaneseAboriginalDance_176.csv
# 📄 處理中：TaiwaneseAboriginalDance_177.csv
# 📄 處理中：TaiwaneseAboriginalDance_178.csv
# 📄 處理中：TaiwaneseAboriginalDance_179.csv
# 📄 處理中：TaiwaneseAboriginalDance_180.csv
# 📄 處理中：TaiwaneseAboriginalDance_181.csv
# 📄 處理中：TaiwaneseAboriginalDance_182.csv
# 📄 處理中：TaiwaneseAboriginalDance_183.csv
# 📄 處理中：TaiwaneseAboriginalDance_184.csv
# 📄 處理中：TaiwaneseAboriginalDance_185.csv
# 📄 處理中：TaiwaneseAboriginalDance_186.csv
# 📄 處理中：TaiwaneseAboriginalDance_187.csv
# 📄 處理中：TaiwaneseAboriginalDance_188.csv
# 📄 處理中：TaiwaneseAboriginalDance_189.csv
# 📄 處理中：TaiwaneseAboriginalDance_190.csv
# 📄 處理中：TaiwaneseAboriginalDance_191.csv
# 📄 處理中：TaiwaneseAboriginalDance_192.csv
# 📄 處理中：TaiwaneseAboriginalDance_193.csv
# 📄 處理中：TaiwaneseAboriginalDance_194.csv
# 📄 處理中：TaiwaneseAboriginalDance_195.csv
# 📄 處理中：TaiwaneseAboriginalDance_196.csv
# 📄 處理中：TaiwaneseAboriginalDance_197.csv
# 📄 處理中：TaiwaneseAboriginalDance_198.csv
# 📄 處理中：TaiwaneseAboriginalDance_199.csv
# 📄 處理中：TaiwaneseAboriginalDance_200.csv
# 📄 處理中：TaiwaneseAboriginalDance_201.csv
# 📄 處理中：TaiwaneseAboriginalDance_202.csv
# 📄 處理中：TaiwaneseAboriginalDance_203.csv
# 📄 處理中：TaiwaneseAboriginalDance_204.csv
# 📄 處理中：TaiwaneseAboriginalDance_205.csv
# 📄 處理中：TaiwaneseAboriginalDance_206.csv
# 📄 處理中：TaiwaneseAboriginalDance_207.csv
# 📄 處理中：TaiwaneseAboriginalDance_208.csv
# 📄 處理中：TaiwaneseAboriginalDance_209.csv
# 📄 處理中：TaiwaneseAboriginalDance_210.csv
# 📄 處理中：TaiwaneseAboriginalDance_211.csv
# 📄 處理中：TaiwaneseAboriginalDance_212.csv
# 📄 處理中：TaiwaneseAboriginalDance_213.csv
# 📄 處理中：TaiwaneseAboriginalDance_214.csv
# 📄 處理中：TaiwaneseAboriginalDance_215.csv
# 📄 處理中：TaiwaneseAboriginalDance_216.csv
# 📄 處理中：TaiwaneseAboriginalDance_217.csv
# 📄 處理中：TaiwaneseAboriginalDance_218.csv
# 📄 處理中：TaiwaneseAboriginalDance_219.csv
# 📄 處理中：TaiwaneseAboriginalDance_220.csv
# 📄 處理中：TaiwaneseAboriginalDance_221.csv
# 📄 處理中：TaiwaneseAboriginalDance_222.csv
# 📄 處理中：TaiwaneseAboriginalDance_223.csv
# 📄 處理中：TaiwaneseAboriginalDance_224.csv
# 📄 處理中：TaiwaneseAboriginalDance_225.csv
# 📄 處理中：TaiwaneseAboriginalDance_226.csv
# 📄 處理中：TaiwaneseAboriginalDance_227.csv
# 📄 處理中：TaiwaneseAboriginalDance_228.csv
# 📄 處理中：TaiwaneseAboriginalDance_229.csv
# 📄 處理中：TaiwaneseAboriginalDance_230.csv
# 📄 處理中：TaiwaneseAboriginalDance_231.csv
# 📄 處理中：TaiwaneseAboriginalDance_232.csv
# 📄 處理中：TaiwaneseAboriginalDance_233.csv
# 📄 處理中：TaiwaneseAboriginalDance_234.csv
# 📄 處理中：TaiwaneseAboriginalDance_235.csv
# 📄 處理中：TaiwaneseAboriginalDance_236.csv
# 📄 處理中：TaiwaneseAboriginalDance_237.csv
# 📄 處理中：TaiwaneseAboriginalDance_238.csv
# 📄 處理中：TaiwaneseAboriginalDance_94.csv
# 📄 處理中：TaiwaneseAboriginalDance_95.csv
# 📄 處理中：TaiwaneseAboriginalDance_96.csv
# 📄 處理中：TaiwaneseAboriginalDance_97.csv
# 📄 處理中：TaiwaneseAboriginalDance_98.csv
# 📄 處理中：TaiwaneseAboriginalDance_99.csv
# 📄 處理中：TapDance_239.csv
# 📄 處理中：TapDance_240.csv
# 📄 處理中：TapDance_241.csv
# 📄 處理中：TapDance_242.csv
# 📄 處理中：TapDance_243.csv
# 📄 處理中：TapDance_244.csv
# 📄 處理中：TapDance_245.csv
# 📄 處理中：TapDance_246.csv
# 📄 處理中：TapDance_247.csv
# 📄 處理中：TapDance_248.csv
# 📄 處理中：TapDance_249.csv
# 📄 處理中：TapDance_250.csv

# %%
# ============================================================
# 5️⃣ 儲存成 JSON
# ============================================================
with open(output_json, "w", encoding="utf-8") as f:
    json.dump(symbol_dict, f, indent=4, ensure_ascii=False)

print(f"🎉 已完成！符號序列儲存於：{output_json}")
# Out:
# 🎉 已完成！符號序列儲存於：symbol_sequences.json
