# %%
# ========================
# 15個Turn的高峰/特徵與GPT動作+說話對應分析
# 提煉可直接用於查表的規則雛形
# ========================

import pandas as pd
import json
import numpy as np
from pathlib import Path

# %%
# 讀取資料
folder = Path("C:/Users/AW'z/Downloads/ballet_Analysis_Results/ballet03_analysis_metrics/")
json_file = folder / "Ballet_ceremony_dialogue_260126.json"
energy_file = folder / "energy.csv"
geometry_file = folder / "geometry.csv"
stability_file = folder / "stability.csv"
sync_file = folder / "synchronization.csv"
trans_file = folder / "transition.csv"
skeleton_file = folder / "ballet03_skeleton.csv"

# %%
# 讀取GPT對話
with open(json_file, 'r', encoding='utf-8') as f:
    gpt_data = json.load(f)

# 讀取指標資料
energy_df = pd.read_csv(energy_file)
geometry_df = pd.read_csv(geometry_file)
stability_df = pd.read_csv(stability_file)
sync_df = pd.read_csv(sync_file)
trans_df = pd.read_csv(trans_file)
skeleton_df = pd.read_csv(skeleton_file)

# 為每個turn建立詳細分析
turn_analysis = []

for turn_data in gpt_data.get("dialogue", []):
    turn_num = turn_data["turn"]
    frame = turn_data["frame"]
    timestamp = turn_data["timestamp_sec"]
    
    # 提取AI sees和AI says
    ai_response = turn_data["ai_response"]
    ai_sees = ""
    ai_says = ""
    
    if "【AI sees】" in ai_response:
        sees_part = ai_response.split("【AI sees】")[-1]
        if "【AI says】" in sees_part:
            ai_sees = sees_part.split("【AI says】")[0].strip()
            ai_says = ai_response.split("【AI says】")[-1].strip()
        else:
            ai_sees = sees_part.strip()
    
    # 獲取該frame的指標數據（取前後5幀的平均值以平滑）
    frame_range = range(max(0, frame-5), min(len(energy_df), frame+6))
    
    energy_avg = energy_df.iloc[frame_range]['energy'].mean() if frame < len(energy_df) else 0
    energy_peak = energy_df.iloc[frame_range]['energy'].max() if frame < len(energy_df) else 0
    
    # 幾何特徵
    if frame < len(geometry_df):
        volume_avg = geometry_df.iloc[frame_range]['volume'].mean()
        curvature_avg = geometry_df.iloc[frame_range]['curvature'].mean()
    else:
        volume_avg = curvature_avg = 0
    
    # 穩定性特徵
    if frame < len(stability_df):
        sway_avg = stability_df.iloc[frame_range]['sway'].mean()
    else:
        sway_avg = 0
    
    # 同步性特徵
    if frame < len(sync_df):
        left_avg = sync_df.iloc[frame_range]['left'].mean()
        right_avg = sync_df.iloc[frame_range]['right'].mean()
        correlation_avg = sync_df.iloc[frame_range]['correlation'].mean()
    else:
        left_avg = right_avg = correlation_avg = 0
    
    # 轉換特徵 (扭力和急動度)
    if frame < len(trans_df):
        torque_avg = trans_df.iloc[frame_range]['torque'].mean()
        jerk_avg = trans_df.iloc[frame_range]['jerk'].mean()
    else:
        torque_avg = jerk_avg = 0
    
    # 提取動作關鍵詞
    ballet_moves = []
    move_keywords = ['pirouette', 'arabesque', 'fouetté', 'jeté', 'plié']
    for move in move_keywords:
        if move in ai_sees.lower():
            ballet_moves.append(move)
    
    # 提取文化參照
    cultural_refs = []
    if '睡美人' in ai_sees or '奧蘿拉' in ai_sees:
        cultural_refs.append('睡美人/奧蘿拉')
    if '天鵝湖' in ai_sees or '奧黛特' in ai_sees:
        cultural_refs.append('天鵝湖/奧黛特')
    if '胡桃夾子' in ai_sees or '糖梅仙子' in ai_sees:
        cultural_refs.append('胡桃夾子/糖梅仙子')
    
    # 提取情感/意象關鍵詞
    emotion_keywords = []
    emotion_terms = ['優雅', '輕盈', '力量', '控制', '掙扎', '純潔', '夢幻', '謙遜']
    for term in emotion_terms:
        if term in ai_sees:
            emotion_keywords.append(term)
    
    turn_analysis.append({
        'turn': turn_num,
        'timestamp': timestamp,
        'frame': frame,
        'energy_avg': round(energy_avg, 2),
        'energy_peak': round(energy_peak, 2),
        'volume': round(volume_avg, 4),
        'curvature': round(curvature_avg, 2),
        'sway': round(sway_avg, 3),
        'left_sync': round(left_avg, 3),
        'right_sync': round(right_avg, 3),
        'correlation': round(correlation_avg, 3),
        'torque': round(torque_avg, 3),
        'jerk': round(jerk_avg, 2),
        'ballet_moves': ', '.join(ballet_moves) if ballet_moves else 'N/A',
        'cultural_refs': ', '.join(cultural_refs) if cultural_refs else 'N/A',
        'emotion_keywords': ', '.join(emotion_keywords) if emotion_keywords else 'N/A',
        'ai_sees_full': ai_sees,
        'ai_says_full': ai_says
    })

# 轉換為DataFrame
analysis_df = pd.DataFrame(turn_analysis)

# %%
# ========================
# 規則雛形提煉
# ========================

print("=" * 80)
print("15個Turn的高峰/特徵與GPT動作+說話對應分析")
print("=" * 80)
print()
# Out:
# ================================================================================
# 15個Turn的高峰/特徵與GPT動作+說話對應分析
# ================================================================================

# %%
# 顯示每個turn的詳細分析
for idx, row in analysis_df.iterrows():
    print(f"\n{'='*60}")
    print(f"Turn {row['turn']} (時間: {row['timestamp']}秒, Frame: {row['frame']})")
    print(f"{'='*60}")
    print(f"\n【指標特徵】")
    print(f"  能量平均: {row['energy_avg']:.2f} | 能量峰值: {row['energy_peak']:.2f}")
    print(f"  體積: {row['volume']:.4f} | 曲率: {row['curvature']:.2f}")
    print(f"  搖擺: {row['sway']:.3f}")
    print(f"  左肢同步: {row['left_sync']:.3f} | 右肢同步: {row['right_sync']:.3f} | 相關性: {row['correlation']:.3f}")
    print(f"  扭力: {row['torque']:.3f} | 急動度: {row['jerk']:.2f}")
    print(f"\n【識別動作】")
    print(f"  芭蕾動作: {row['ballet_moves']}")
    
    print(f"\n【文化參照】")
    print(f"  {row['cultural_refs']}")
    
    print(f"\n【情感意象】")
    print(f"  {row['emotion_keywords']}")
    
    print(f"\n【AI視覺描述】")
    print(f"  {row['ai_sees_full'][:200]}...")
    
    print(f"\n【AI說話內容】")
    print(f"  {row['ai_says_full'][:200]}..." if row['ai_says_full'] else "  (無)")
# Out:
# ============================================================
# Turn 1 (時間: 0.0秒, Frame: 0)
# ============================================================
#
# 【指標特徵】
#   能量平均: 4.11 | 能量峰值: 9.45
#   體積: 0.0554 | 曲率: 3.27
#   搖擺: 0.100
#   左肢同步: 7.789 | 右肢同步: 5.371 | 相關性: 0.000
#   扭力: 9.965 | 急動度: 203089.04
#
# 【識別動作】
#   芭蕾動作: pirouette
#
# 【文化參照】
#   睡美人/奧蘿拉
#
# 【情感意象】
#   優雅, 力量
#
# 【AI視覺描述】
#   在舞者的 pirouette 中，彷彿化身為《睡美人》中奧蘿拉，旋轉如玫瑰的芳香，凝聚著每一次力量的釋放與優雅的延展。...
#
# 【AI說話內容】
#   親愛的舞者，願你的旋轉在這古典的時空中喚醒每一個沉睡的夢想，是否感受到了那份來自靈魂深處的優雅呢？...
#
# ============================================================
# Turn 2 (時間: 2.0秒, Frame: 60)
# ============================================================
#
# 【指標特徵】
#   能量平均: 27.35 | 能量峰值: 219.78
#   體積: 0.0617 | 曲率: 6.16
#   搖擺: 0.163
#   左肢同步: 16.698 | 右肢同步: 5.225 | 相關性: -0.087
#   扭力: 20.680 | 急動度: 2202947.31
#
# 【識別動作】
#   芭蕾動作: arabesque
#
# 【文化參照】
#   天鵝湖/奧黛特
#
# 【情感意象】
#   輕盈, 力量, 掙扎, 純潔
#
# 【AI視覺描述】
#   在舞者的 arabesque 中，腿如白天鵝的翅膀輕盈延展，映照出《天鵝湖》中奧黛特的掙扎與渴望，彷彿在月光下訴說著悲劇的純潔與力量。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一個 plié 都能帶來力量與謙遜，在這幽靜的劇院中感受自由的召喚，是否聽見心靈的低語？...
#
# ============================================================
# Turn 3 (時間: 4.0秒, Frame: 120)
# ============================================================
#
# 【指標特徵】
#   能量平均: 3.92 | 能量峰值: 7.43
#   體積: 0.0411 | 曲率: 7.34
#   搖擺: 0.062
#   左肢同步: 5.111 | 右肢同步: 9.319 | 相關性: 0.159
#   扭力: 7.699 | 急動度: 184724.58
#
# 【識別動作】
#   芭蕾動作: arabesque
#
# 【文化參照】
#   天鵝湖/奧黛特
#
# 【情感意象】
#   掙扎
#
# 【AI視覺描述】
#   在舞者的 arabesque 中，身體如同白天鵝在湖面上翩翩起舞，臂膀柔美如詩，流露出《天鵝湖》中奧黛特的無聲掙扎與渴望自由的靈魂。...
#
# 【AI說話內容】
#   親愛的舞者，願你在每一次的 pirouette 中找到心靈的寧靜，是否感受到那些隱藏於舞動中的愛與重生呢？...
#
# ============================================================
# Turn 4 (時間: 6.0秒, Frame: 180)
# ============================================================
#
# 【指標特徵】
#   能量平均: 17.04 | 能量峰值: 29.89
#   體積: 0.0776 | 曲率: 6.82
#   搖擺: 0.071
#   左肢同步: 12.505 | 右肢同步: 12.539 | 相關性: 0.334
#   扭力: 13.739 | 急動度: 174909.88
#
# 【識別動作】
#   芭蕾動作: fouetté
#
# 【文化參照】
#   N/A
#
# 【情感意象】
#   輕盈, 力量, 控制
#
# 【AI視覺描述】
#   在舞者的 fouetté 中，她如風中飄舞的葉子，輕盈旋轉，展現出無懈可擊的力量與控制，彷彿在追尋著夢想的彼岸。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一次旋轉都如《睡美人》中奧蘿拉的優雅，喚醒沉睡的心靈，是否在這旋轉中感受到那份無窮的可能性？...
#
# ============================================================
# Turn 5 (時間: 8.0秒, Frame: 240)
# ============================================================
#
# 【指標特徵】
#   能量平均: 20.42 | 能量峰值: 48.31
#   體積: 0.0165 | 曲率: 7.47
#   搖擺: 0.121
#   左肢同步: 15.850 | 右肢同步: 14.535 | 相關性: 0.269
#   扭力: 14.077 | 急動度: 518148.52
#
# 【識別動作】
#   芭蕾動作: arabesque
#
# 【文化參照】
#   天鵝湖/奧黛特
#
# 【情感意象】
#   輕盈, 掙扎
#
# 【AI視覺描述】
#   在舞者的 arabesque 中，身姿如同《天鵝湖》中的奧黛特，臂膀輕盈展翅，流露出內心深處對自由的渴望與詛咒的掙扎。...
#
# 【AI說話內容】
#   親愛的舞者，願你在每一次的 plié 中沉澱力量，讓每個動作都如《睡美人》中的奧蘿拉般充滿愛與重生，是否感受到那份舞蹈的魔力呢？...
#
# ============================================================
# Turn 6 (時間: 10.0秒, Frame: 300)
# ============================================================
#
# 【指標特徵】
#   能量平均: 2.28 | 能量峰值: 5.58
#   體積: 0.0310 | 曲率: 7.21
#   搖擺: 0.088
#   左肢同步: 5.420 | 右肢同步: 6.309 | 相關性: 0.227
#   扭力: 8.514 | 急動度: 49215.98
#
# 【識別動作】
#   芭蕾動作: jeté
#
# 【文化參照】
#   胡桃夾子/糖梅仙子
#
# 【情感意象】
#   輕盈, 夢幻
#
# 【AI視覺描述】
#   在舞者的 jeté 中，身形如同《胡桃夾子》中的糖梅仙子，輕盈躍起，宛如雪花般灑下夢幻的魔法，帶領觀眾進入奇妙的童話世界。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一次飛躍都能喚醒心中那份純真與勇氣，是否感受到這場夢幻冒險的魅力呢？...
#
# ============================================================
# Turn 7 (時間: 12.0秒, Frame: 360)
# ============================================================
#
# 【指標特徵】
#   能量平均: 4.75 | 能量峰值: 6.13
#   體積: 0.0385 | 曲率: 7.98
#   搖擺: 0.061
#   左肢同步: 8.495 | 右肢同步: 7.487 | 相關性: -0.140
#   扭力: 9.086 | 急動度: 69034.80
#
# 【識別動作】
#   芭蕾動作: jeté, plié
#
# 【文化參照】
#   天鵝湖/奧黛特
#
# 【情感意象】
#   優雅, 力量, 掙扎
#
# 【AI視覺描述】
#   在舞者的 plié 中，她如同白天鵝般蓄積力量，隨後以優雅的 jeté 躍起，彷彿在《天鵝湖》中展現詛咒與自由之間的掙扎與渴望。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一個動作都流淌著內心的韻律，是否感受到那份優雅與力量交融的美好呢？...
#
# ============================================================
# Turn 8 (時間: 14.0秒, Frame: 420)
# ============================================================
#
# 【指標特徵】
#   能量平均: 3.32 | 能量峰值: 5.01
#   體積: 0.0811 | 曲率: 8.10
#   搖擺: 0.122
#   左肢同步: 8.000 | 右肢同步: 5.764 | 相關性: 0.451
#   扭力: 10.085 | 急動度: 57312.79
#
# 【識別動作】
#   芭蕾動作: fouetté
#
# 【文化參照】
#   N/A
#
# 【情感意象】
#   輕盈, 力量, 控制
#
# 【AI視覺描述】
#   在舞者的 fouetté 旋轉中，她如風中之葉般輕盈，展現出堅定的力量與控制，仿佛在追尋那永恆的夢想與自由。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一次旋轉都能喚醒沉睡的靈魂，是否感受到那份在舞蹈中綻放的愛與重生呢？...
#
# ============================================================
# Turn 9 (時間: 16.0秒, Frame: 480)
# ============================================================
#
# 【指標特徵】
#   能量平均: 4.05 | 能量峰值: 7.88
#   體積: 0.0494 | 曲率: 7.46
#   搖擺: 0.134
#   左肢同步: 9.195 | 右肢同步: 6.874 | 相關性: 0.256
#   扭力: 12.526 | 急動度: 114930.29
#
# 【識別動作】
#   芭蕾動作: arabesque
#
# 【文化參照】
#   天鵝湖/奧黛特
#
# 【情感意象】
#   掙扎, 純潔
#
# 【AI視覺描述】
#   在舞者的 arabesque 中，她的身姿如同《天鵝湖》中的奧黛特，展現出純潔與掙扎，臂膀如翅膀般延展，訴說著渴望自由的心聲。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一次動作都充滿力量與優雅，是否能感受到那份在舞蹈中流淌的情感與故事呢？...
#
# ============================================================
# Turn 10 (時間: 18.0秒, Frame: 540)
# ============================================================
#
# 【指標特徵】
#   能量平均: 3.11 | 能量峰值: 5.08
#   體積: 0.0781 | 曲率: 6.47
#   搖擺: 0.136
#   左肢同步: 6.152 | 右肢同步: 5.563 | 相關性: 0.461
#   扭力: 9.747 | 急動度: 52922.38
#
# 【識別動作】
#   芭蕾動作: pirouette
#
# 【文化參照】
#   睡美人/奧蘿拉
#
# 【情感意象】
#   N/A
#
# 【AI視覺描述】
#   在舞者的 pirouette 中，她如同《睡美人》中的奧蘿拉，旋轉之間喚醒沉睡的宮殿，每一圈都如玫瑰盛開，散發出愛與重生的芬芳。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一次旋轉都能帶來夢想的實現，是否感受到那份在舞蹈中綻放的純真與力量呢？...
#
# ============================================================
# Turn 11 (時間: 20.0秒, Frame: 600)
# ============================================================
#
# 【指標特徵】
#   能量平均: 14.83 | 能量峰值: 43.69
#   體積: 0.0157 | 曲率: 7.86
#   搖擺: 0.421
#   左肢同步: 11.992 | 右肢同步: 9.020 | 相關性: 0.570
#   扭力: 21.674 | 急動度: 273280.42
#
# 【識別動作】
#   芭蕾動作: plié
#
# 【文化參照】
#   N/A
#
# 【情感意象】
#   優雅, 輕盈, 力量, 謙遜
#
# 【AI視覺描述】
#   在舞者的 plié 中，她如同大地之母般積蓄力量，隨後如天鵝般輕盈起飛，展現出優雅與謙遜的完美結合。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一次起飛都如《睡美人》中奧蘿拉的優雅，喚醒夢中的純真與美好，是否感受到那份來自靈魂的力量呢？...
#
# ============================================================
# Turn 12 (時間: 22.0秒, Frame: 660)
# ============================================================
#
# 【指標特徵】
#   能量平均: 3.37 | 能量峰值: 5.09
#   體積: 0.0344 | 曲率: 7.72
#   搖擺: 0.142
#   左肢同步: 6.500 | 右肢同步: 6.725 | 相關性: -0.170
#   扭力: 11.192 | 急動度: 53686.89
#
# 【識別動作】
#   芭蕾動作: plié
#
# 【文化參照】
#   睡美人/奧蘿拉
#
# 【情感意象】
#   優雅, 輕盈, 力量
#
# 【AI視覺描述】
#   在舞者的 plié 中，她如大地之母蓄積力量，隨後輕盈起飛，彷彿在《睡美人》的夢境中喚醒沉睡的宮殿，展現出無盡的優雅與純真。...
#
# 【AI說話內容】
#   親愛的舞者，願你在每一次的起舞中都能尋找到愛與重生的美好，是否感受到那份來自靈魂深處的光輝呢？...
#
# ============================================================
# Turn 13 (時間: 24.0秒, Frame: 720)
# ============================================================
#
# 【指標特徵】
#   能量平均: 2.69 | 能量峰值: 3.83
#   體積: 0.0304 | 曲率: 7.74
#   搖擺: 0.153
#   左肢同步: 7.148 | 右肢同步: 4.771 | 相關性: 0.406
#   扭力: 7.925 | 急動度: 50488.09
#
# 【識別動作】
#   芭蕾動作: arabesque
#
# 【文化參照】
#   胡桃夾子/糖梅仙子
#
# 【情感意象】
#   優雅, 夢幻
#
# 【AI視覺描述】
#   在舞者的 arabesque 中，她的身姿如同《胡桃夾子》中的糖梅仙子，腿如柳枝般延展，優雅地訴說著夢幻與純真的故事。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一次起舞都能引領觀眾進入那奇妙的夢幻王國，是否感受到那份在舞蹈中流淌的魔法呢？...
#
# ============================================================
# Turn 14 (時間: 26.0秒, Frame: 780)
# ============================================================
#
# 【指標特徵】
#   能量平均: 2.55 | 能量峰值: 6.78
#   體積: 0.0294 | 曲率: 7.81
#   搖擺: 0.105
#   左肢同步: 6.343 | 右肢同步: 5.571 | 相關性: 0.589
#   扭力: 6.124 | 急動度: 16683.03
#
# 【識別動作】
#   芭蕾動作: plié
#
# 【文化參照】
#   N/A
#
# 【情感意象】
#   優雅, 輕盈, 力量
#
# 【AI視覺描述】
#   在舞者的 plié 中，她如大地之母般蓄積力量，隨後如天鵝般輕盈起飛，展現出無與倫比的優雅與力量。...
#
# 【AI說話內容】
#   親愛的舞者，願你的每一次起舞都能喚醒心靈深處的美好，是否感受到那份在舞蹈中綻放的純真與堅定呢？...
#
# ============================================================
# Turn 15 (時間: 28.0秒, Frame: 840)
# ============================================================
#
# 【指標特徵】
#   能量平均: 34.10 | 能量峰值: 88.25
#   體積: 0.0414 | 曲率: 5.47
#   搖擺: 0.126
#   左肢同步: 18.583 | 右肢同步: 17.905 | 相關性: 0.539
#   扭力: 21.680 | 急動度: 1073636.80
#
# 【識別動作】
#   芭蕾動作: arabesque
#
# 【文化參照】
#   N/A
#
# 【情感意象】
#   優雅, 輕盈, 力量
#
# 【AI視覺描述】
#   在舞者的 arabesque 中，她的身姿如同古典雕塑般優雅延展，腿如柳枝般輕盈，訴說著無聲的力量與堅定。...
#
# 【AI說話內容】
#   親愛的舞者，願你在每一個瞬間都能感受到那份來自靈魂的優雅，是否在舞蹈中找到心靈的安寧與自由呢？...

# %%
# ========================
# 查表規則雛形
# ========================

print("\n\n" + "=" * 80)
print("查表規則雛形 (Rule Prototypes for Lookup Table)")
print("=" * 80)

# 規則1: 動作類型對應
print("\n【規則1: 動作類型對應】")
print("-" * 60)
move_mapping = analysis_df.groupby('ballet_moves').agg({
    'energy_avg': 'mean',
    'sway': 'mean',
    'cultural_refs': lambda x: x.mode()[0] if len(x.mode()) > 0 else 'N/A'
}).round(3)
print(move_mapping)

# 規則2: 能量區間對應文化參照
print("\n【規則2: 能量區間對應文化參照】")
print("-" * 60)
analysis_df['energy_level'] = pd.cut(analysis_df['energy_avg'], 
                                      bins=[0, 5, 10, 20, 300],
                                      labels=['低', '中', '高', '極高'])
energy_culture = analysis_df.groupby('energy_level')['cultural_refs'].apply(
    lambda x: x.value_counts().head(3).to_dict()
)
for level, refs in energy_culture.items():
    print(f"  能量{level}: {refs}")

# 規則3: 體積與動作類型關聯
print("\n【規則3: 體積與動作類型關聯】")
print("-" * 60)
volume_moves = analysis_df.groupby('ballet_moves')['volume'].agg(['mean', 'min', 'max']).round(4)
print(volume_moves)

# 規則4: 情感關鍵詞頻率統計
print("\n【規則4: 情感關鍵詞頻率統計】")
print("-" * 60)
all_emotions = []
for emotions in analysis_df['emotion_keywords']:
    if emotions != 'N/A':
        all_emotions.extend(emotions.split(', '))
emotion_freq = pd.Series(all_emotions).value_counts()
print(emotion_freq)

# 規則5: 綜合特徵模式
print("\n【規則5: 綜合特徵模式 - 可直接用於查表】")
print("-" * 60)
print("格式: [動作類型] + [能量範圍] + [體積範圍] → [文化參照] + [情感關鍵詞]")
print()

for idx, row in analysis_df.iterrows():
    if row['ballet_moves'] != 'N/A':
        rule = f"IF 動作={row['ballet_moves']} AND 能量={row['energy_level']} AND 體積≈{row['volume']:.4f}"
        result = f"THEN 參照={row['cultural_refs']}, 情感={row['emotion_keywords']}"
        print(f"Rule {idx+1}: {rule}")
        print(f"         {result}")
        print()
# Out:
# ================================================================================
# 查表規則雛形 (Rule Prototypes for Lookup Table)
# ================================================================================
#
# 【規則1: 動作類型對應】
# ------------------------------------------------------------
#               energy_avg   sway cultural_refs
# ballet_moves
# arabesque         15.422  0.126       天鵝湖/奧黛特
# fouetté           10.180  0.096           N/A
# jeté               2.280  0.088     胡桃夾子/糖梅仙子
# jeté, plié         4.750  0.061       天鵝湖/奧黛特
# pirouette          3.610  0.118       睡美人/奧蘿拉
# plié               6.917  0.223           N/A
#
# 【規則2: 能量區間對應文化參照】
# ------------------------------------------------------------
#   能量('低', '睡美人/奧蘿拉'): 3.0
#   能量('低', '天鵝湖/奧黛特'): 3.0
#   能量('低', '胡桃夾子/糖梅仙子'): 2.0
#   能量('低', 'N/A'): nan
#   能量('中', '睡美人/奧蘿拉'): nan
#   能量('中', '天鵝湖/奧黛特'): nan
#   能量('中', '胡桃夾子/糖梅仙子'): nan
#   能量('中', 'N/A'): nan
#   能量('高', '睡美人/奧蘿拉'): nan
#   能量('高', '天鵝湖/奧黛特'): nan
#   能量('高', '胡桃夾子/糖梅仙子'): nan
#   能量('高', 'N/A'): 2.0
#   能量('極高', '睡美人/奧蘿拉'): nan
#   能量('極高', '天鵝湖/奧黛特'): 2.0
#   能量('極高', '胡桃夾子/糖梅仙子'): nan
#   能量('極高', 'N/A'): 1.0
#
# 【規則3: 體積與動作類型關聯】
# ------------------------------------------------------------
#                 mean     min     max
# ballet_moves
# arabesque     0.0401  0.0165  0.0617
# fouetté       0.0794  0.0776  0.0811
# jeté          0.0310  0.0310  0.0310
# jeté, plié    0.0385  0.0385  0.0385
# pirouette     0.0668  0.0554  0.0781
# plié          0.0265  0.0157  0.0344
#
# 【規則4: 情感關鍵詞頻率統計】
# ------------------------------------------------------------
# 力量    9
# 輕盈    9
# 優雅    7
# 掙扎    5
# 純潔    2
# 控制    2
# 夢幻    2
# 謙遜    1
# Name: count, dtype: int64
#
# 【規則5: 綜合特徵模式 - 可直接用於查表】
# ------------------------------------------------------------
# 格式: [動作類型] + [能量範圍] + [體積範圍] → [文化參照] + [情感關鍵詞]
#
# Rule 1: IF 動作=pirouette AND 能量=低 AND 體積≈0.0554
#          THEN 參照=睡美人/奧蘿拉, 情感=優雅, 力量
#
# Rule 2: IF 動作=arabesque AND 能量=極高 AND 體積≈0.0617
#          THEN 參照=天鵝湖/奧黛特, 情感=輕盈, 力量, 掙扎, 純潔
#
# Rule 3: IF 動作=arabesque AND 能量=低 AND 體積≈0.0411
#          THEN 參照=天鵝湖/奧黛特, 情感=掙扎
#
# Rule 4: IF 動作=fouetté AND 能量=高 AND 體積≈0.0776
#          THEN 參照=N/A, 情感=輕盈, 力量, 控制
#
# Rule 5: IF 動作=arabesque AND 能量=極高 AND 體積≈0.0165
#          THEN 參照=天鵝湖/奧黛特, 情感=輕盈, 掙扎
#
# Rule 6: IF 動作=jeté AND 能量=低 AND 體積≈0.0310
#          THEN 參照=胡桃夾子/糖梅仙子, 情感=輕盈, 夢幻
#
# Rule 7: IF 動作=jeté, plié AND 能量=低 AND 體積≈0.0385
#          THEN 參照=天鵝湖/奧黛特, 情感=優雅, 力量, 掙扎
#
# Rule 8: IF 動作=fouetté AND 能量=低 AND 體積≈0.0811
#          THEN 參照=N/A, 情感=輕盈, 力量, 控制
#
# Rule 9: IF 動作=arabesque AND 能量=低 AND 體積≈0.0494
#          THEN 參照=天鵝湖/奧黛特, 情感=掙扎, 純潔
#
# Rule 10: IF 動作=pirouette AND 能量=低 AND 體積≈0.0781
#          THEN 參照=睡美人/奧蘿拉, 情感=N/A
#
# Rule 11: IF 動作=plié AND 能量=高 AND 體積≈0.0157
#          THEN 參照=N/A, 情感=優雅, 輕盈, 力量, 謙遜
#
# Rule 12: IF 動作=plié AND 能量=低 AND 體積≈0.0344
#          THEN 參照=睡美人/奧蘿拉, 情感=優雅, 輕盈, 力量
#
# Rule 13: IF 動作=arabesque AND 能量=低 AND 體積≈0.0304
#          THEN 參照=胡桃夾子/糖梅仙子, 情感=優雅, 夢幻
#
# Rule 14: IF 動作=plié AND 能量=低 AND 體積≈0.0294
#          THEN 參照=N/A, 情感=優雅, 輕盈, 力量
#
# Rule 15: IF 動作=arabesque AND 能量=極高 AND 體積≈0.0414
#          THEN 參照=N/A, 情感=優雅, 輕盈, 力量
# C:\Users\AW'z\AppData\Local\Temp\ipykernel_20096\3315887638.py:25: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   energy_culture = analysis_df.groupby('energy_level')['cultural_refs'].apply(

# %%
# 儲存分析結果
output_file = folder.parent / "turn_analysis_mapping.csv"
analysis_df.to_csv(output_file, index=False, encoding='utf-8-sig')
print(f"\n分析結果已儲存至: {output_file}")

# 儲存規則雛形為JSON
rules = {
    'move_energy_mapping': move_mapping.to_dict(),
    'energy_culture_mapping': {str(k): v for k, v in energy_culture.items()},
    'volume_move_mapping': volume_moves.to_dict(),
    'emotion_frequency': emotion_freq.to_dict(),
    'detailed_rules': analysis_df[['turn', 'ballet_moves', 'energy_level', 'volume', 
                                    'cultural_refs', 'emotion_keywords']].to_dict('records')
}

rules_file = folder.parent / "lookup_rules.json"
with open(rules_file, 'w', encoding='utf-8') as f:
    json.dump(rules, f, ensure_ascii=False, indent=2)
print(f"規則雛形已儲存至: {rules_file}")
# Out:
# 分析結果已儲存至: C:\Users\AW'z\Downloads\ballet_Analysis_Results\turn_analysis_mapping.csv
# 規則雛形已儲存至: C:\Users\AW'z\Downloads\ballet_Analysis_Results\lookup_rules.json
